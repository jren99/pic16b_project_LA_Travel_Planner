# %% [markdown]
# # Webscraping TripAdvisor
# ## -- All recommended restaurants on TripAdvisor

# %% [markdown]
# ### Modules
#
# The modules we will be using for this version of web scraping are:
#
# - **pandas**: We will later use Pandas to create a dataframe for the name of each recommended restaurant and its site link information after webscraping TripAdvisor.
#
# - **requests**: The module that enables us to send http requests so that we can receive all the response data.
#
# - **BeautifulSoup**: I've searched online regarding more tutorials of webscraping and learned that BeautifulSoup is an extremely useful module when trying to get data from html.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as soup

# %% [markdown]
# # Part 1: Data Preparation

# %% [markdown]
# ## Step 1: Top 30 restaurants

# %% [markdown]
# ### Get the Site Link with the Name
#
# Firstly, we use the requests and BeautifulSoup modules to get the response data from the website. And then, we observed the "Developer Tools" on the website page for webscraping the information we want.

# %%
html_main = requests.get("https://www.tripadvisor.com/Restaurants-g32655-Los_Angeles_California.html")
bsobj_main = soup(html_main.content, "lxml")

# %%
rank = []
restaurant_name = []
style = []
rate_score = []
restaurant_link = []
for s1 in bsobj_main.find_all("div", class_ = "_1llCuDZj"):
    if s1["data-test"] != "SL_list_item":
        rank.append(s1.find("a", class_="_15_ydu6b").text.split(". ")[0:1][0])
        restaurant_name.append(s1.find("a", class_="_15_ydu6b").text.split(". ")[1:2])
        style.append(s1.find("div", class_ = "MIajtJFg _1cBs8huC _3d9EnJpt").text.split("$")[0])
            
        for s2 in s1.find_all("div", class_ = "MIajtJFg _1cBs8huC"):
            if s2.svg == None:
                rate_score.append("0 of 5 bubbles")
            else:
                rate_score.append(s2.svg["aria-label"])
            
        restaurant_link.append(s1.find("div", class_="wQjYiB7z").a["href"])

# %% [markdown]
# ## Step 2: The rest of the restaurants - 13460 recommended restaurants in Los Angeles

# %% [markdown]
# Use the similar way in step 1, we can get all the restaurant information on the rest of the webpages on TripAdvisor.

# %%
top_15000 = list(range(30, 15000, 30))

# %%
for num in top_15000:
    html_main = requests.get("https://www.tripadvisor.com/RestaurantSearch-g32655-oa" + str(num) + "-a_geobroaden.true-Los_Angeles_California.html")
    bsobj_main = soup(html_main.content, "lxml")
    
    for s1 in bsobj_main.find_all("div", class_ = "_1llCuDZj"):
        if s1["data-test"] != "SL_list_item":
            rank.append(s1.find("a", class_="_15_ydu6b").text.split(". ")[0:1][0])
            restaurant_name.append(s1.find("a", class_="_15_ydu6b").text.split(". ")[1:2])
            style.append(s1.find("div", class_ = "MIajtJFg _1cBs8huC _3d9EnJpt").text.split("$")[0])
            
            for s2 in s1.find_all("div", class_ = "MIajtJFg _1cBs8huC"):
                if s2.svg == None:
                    rate_score.append("0 of 5 bubbles")
                else:
                    rate_score.append(s2.svg["aria-label"])
            
            restaurant_link.append(s1.find("div", class_="wQjYiB7z").a["href"])

# %% [markdown]
# ## Step 3: Make a dataFrame for all the webscraping information

# %%
restaurant_name_update = []
for name in restaurant_name:
    restaurant_name_update.append(name[0])

# %%
restaurant_link_update = []
for site in restaurant_link:
    restaurant_link_update.append("https://www.tripadvisor.com/" + site)

# %% [markdown]
# ### There are 13460 recommended restaurants in Los Angeles! After 13460, the restaurants are nearby Los Angeles that we may neglect.

# %%
data = {"Rank": rank[:13460], "Restaurant Name": restaurant_name_update[:13460], "Style": style[:13460], "Rate": rate_score[:13460], "Site Link": restaurant_link_update[:13460]}
df = pd.DataFrame.from_dict(data)
df
# Out:
#         Rank                       Restaurant Name              Style  \
# 0          1                                n/naka    Japanese, Sushi
# 1          2                  Raffaello Ristorante            Italian
# 2          3     Brent's Delicatessen & Restaurant     American, Deli
# 3          4                            Providence            Seafood
# 4          5                      Angelini Osteria  Italian, Sicilian
# ...      ...                                   ...                ...
# 13455  13456  Sweet Bakery Grocery & Kabob Factory
# 13456  13457                 SanSai Japanese Grill
# 13457  13458                Winchell's Donut House           American
# 13458  13459                Winchell's Donut House           American
# 13459  13460                               Sushi2u
#
#                    Rate                                          Site Link
# 0      5.0 of 5 bubbles  https://www.tripadvisor.com//Restaurant_Review...
# 1      4.5 of 5 bubbles  https://www.tripadvisor.com//Restaurant_Review...
# 2      4.5 of 5 bubbles  https://www.tripadvisor.com//Restaurant_Review...
# 3      4.5 of 5 bubbles  https://www.tripadvisor.com//Restaurant_Review...
# 4      4.5 of 5 bubbles  https://www.tripadvisor.com//Restaurant_Review...
# ...                 ...                                                ...
# 13455    0 of 5 bubbles  https://www.tripadvisor.com//Restaurant_Review...
# 13456    0 of 5 bubbles  https://www.tripadvisor.com//Restaurant_Review...
# 13457    0 of 5 bubbles  https://www.tripadvisor.com//Restaurant_Review...
# 13458    0 of 5 bubbles  https://www.tripadvisor.com//Restaurant_Review...
# 13459    0 of 5 bubbles  https://www.tripadvisor.com//Restaurant_Review...
#
# [13460 rows x 5 columns]

# %% [markdown]
# ## Step 3: CSV File -- There are 13460 recommended restaurants on TripAdvisor in total!
#
# We have successfully finished webscraping all the recommended restaurants on TripAdvisor. We want to save them into a csv file for convenience.

# %%
df.to_csv("13460_restaurant.csv")

# %% [markdown]
# # Part 2: Web App Simulation

# %% [markdown]
# ## Step 1: Show all the restaurants to the users for selection

# %%
restaurant_name_update[:13460]
# Out:
# ['n/naka',
#  'Raffaello Ristorante',
#  "Brent's Delicatessen & Restaurant",
#  'Providence',
#  'Angelini Osteria',
#  'Maccheroni Republic',
#  'Sushi Gen',
#  'Cafe Gratitude',
#  "Langer's",
#  'Toast Bakery Cafe',
#  'Karl Strauss Brewing Company',
#  'Flake',
#  'Parkway Grill',
#  'Magic Castle',
#  'Nickel Diner',
#  'Redbird',
#  'Pampas Grill',
#  'Genwa Korean BBQ',
#  'Lemonade',
#  'The Boiling Crab',
#  'The Luggage Room Pizzeria',
#  'Craft Los Angeles',
#  "Raffi's Place Restaurant",
#  "Foxy's Restaurant",
#  'Aroma Coffee & Tea',
#  'SUGARFISH by sushi nozawa',
#  'Off Vine',
#  'Din Tai Fung',
#  'The Griddle Cafe',
#  "Ca' Del Sole",
#  "Cassell's Hamburgers",
#  'The Factory Kitchen',
#  'Perch',
#  'Cleo Hollywood',
#  'Republique',
#  "Gus's Barbecue - South Pasadena",
#  "Gale's Italian Restaurant and Bar",
#  "Aliki's Greek Taverna",
#  'Musso & Frank Grill',
#  "Truxton's American Bistro",
#  'Tatsu Ramen',
#  'Baco Mercat',
#  'Bossa Nova',
#  'Ayara Thai Cuisine',
#  'Sushi A Go Go',
#  'Water Grill',
#  "The Butcher's Daughter",
#  'Crossroads',
#  'Cafe Gratitude',
#  'Getty Center Restaurant',
#  'Baby Blues BBQ',
#  "Houston's",
#  "Russell's",
#  "Vivian's Millenium Cafe",
#  'Bestia',
#  'The Counter Downtown L.A.',
#  'La Grande Orange Cafe',
#  'Animal',
#  'A.O.C.',
#  'The Little Door',
#  'The Front Yard',
#  'Culina',
#  'Malibu Farm Pier Cafe',
#  'Stout Burgers & Beers',
#  "Ruby's Diner",
#  'Katsuya Hollywood',
#  'Good Neighbor',
#  'Pizzeria Mozza',
#  'Umami Burger',
#  'Rainbow Bar & Grill',
#  'The Coffee Company',
#  'Union',
#  'Madeo',
#  'Home Restaurant',
#  'The Original Pantry',
#  '25 Degrees',
#  "Monsieur Marcel's",
#  'Granville',
#  'Wood Ranch BBQ & Grill',
#  "Canter's Deli",
#  'Drago Centro',
#  'Cafe Santorini',
#  'Blu Jam Cafe',
#  'Venice Ale House',
#  '26 Beach Cafe',
#  'Bludsos BBQ',
#  'Faith & Flower',
#  'El Compadre',
#  "Cecconi's West Hollywood",
#  'Superba Food + Bread',
#  'Otium Restaurant',
#  'california PIZZA KITCHEN',
#  '101 Coffee Shop',
#  'Osteria Mozza',
#  'Napa Valley Grille',
#  'The Ivy',
#  'Yamashiro Hollywood',
#  'Swingers',
#  'Julienne',
#  "Pann's Restaurant",
#  'Apple Pan',
#  'The Palm - L.A',
#  'Arroyo Chop House',
#  "Maggiano's - Farmers Market",
#  "Roscoe's House of Chicken & Waffles",
#  "Damon's Steak House",
#  'Yard House',
#  '71Above Restaurant and Skylounge',
#  'Carlitos Gardel',
#  "Pig 'N' Whistle",
#  'IHOP',
#  'Daikokuya',
#  'Beauty & Essex',
#  'Johnny Rockets',
#  'Petit Trois',
#  'Bubba Gump Shrimp Co.',
#  "Mel's Drive-In",
#  'Catch LA',
#  'Hinano Cafe',
#  'Fogo de Chao Brazilian Steakhouse',
#  'Industriel',
#  "Lawry's the Prime Rib",
#  'Daily Grill',
#  'Guelaguetza Restaurante',
#  'Scopa Italian Roots',
#  'Barton G',
#  'Newport Seafood Restaurant',
#  'Mohawk Bend',
#  "Tam O'Shanter",
#  "Larry's",
#  'WeHo Bistro',
#  'Hard Rock Cafe',
#  "Connie & Ted's",
#  'The Stinking Rose',
#  'El Coyote',
#  'Masa of Echo Park',
#  'Wurstkuche Restaurant Venice Beach',
#  "JW's Steakhouse",
#  'The Rose Venice',
#  'Fogo de Chao Brazilian Steakhouse',
#  "Figtree's Cafe",
#  'Yang Chow',
#  'Nobu Los Angeles',
#  'El Tepeyac',
#  'Matsuhisa',
#  'The Venice Whaler',
#  'Daikokuya Ramen',
#  'Tao',
#  'Happy Diner',
#  'TART',
#  "Slater's 50/50",
#  'Sol y Luna',
#  'El Cholo Restaurant',
#  'Gjelina',
#  'Beachwood Cafe',
#  "Du-par's Restaurant & Bakery",
#  'James Beach',
#  "Fleming's Prime Steakhouse & Wine Bar",
#  'Sushi Katsu-ya',
#  'Whole Foods Market',
#  'NORMS Restaurant',
#  'Marmalade Cafe',
#  "Roscoe's House of Chicken & Waffles",
#  'Katana LA',
#  'Green Street Restaurant',
#  'Kreation Kafe',
#  'Laurel Hardware',
#  "Carney's",
#  'Blujam Cafe',
#  'Saddle Ranch Chop House',
#  'Mi Piace',
#  'Broken Spanish',
#  "Jino's Pars - Persian and Italian restaurant",
#  'Hae Jang Chon Korean BBQ Restaurant',
#  "Rock'N Fish",
#  "Park's BBQ",
#  'Luv2Eat Thai Bistro',
#  'Blue Cow Kitchen & Bar',
#  'Border Grill Downtown LA',
#  'JOEY DTLA',
#  'WP24',
#  "Little Dom's",
#  "Hugo's",
#  'True Food Kitchen',
#  'Pokinometry',
#  'Manuela',
#  'The Terrace at The Langham',
#  'Soowon Galbi',
#  'Cafe Gratitude',
#  'Quarters',
#  'Urban Masala',
#  "Rex's Cafe",
#  'Spice Affair',
#  "Marston's",
#  'Koi Restaurant',
#  'Taix French Country Cuisine',
#  'Wolfgang Puck Bar & Grill - LA Live',
#  'Shiro',
#  'Osteria La Buca',
#  'Oomasa',
#  "Papa Cristo's Greek Grill and Market",
#  'Stout burgers and beers',
#  "Te'Kila",
#  'SunCafe Organic',
#  'The Bar at Hotel Bel-Air',
#  'Eataly',
#  'Little Pine Restaurant',
#  'Olive & Thyme',
#  'Bavel',
#  'Green Onion',
#  'Kang Hodong Baekjeong',
#  'Plan Check Kitchen & Bar',
#  'Sage Plant Based Bistro & Brewery',
#  'Marugame Monzo',
#  'Charcoal Venice',
#  'Kings Road Cafe',
#  'Si Laa Thai',
#  'The Morrison',
#  'Salsa & Beer',
#  'Le Petit Four',
#  "Joselito's Mexican Food",
#  'Pine & Crane',
#  'Cheebo',
#  'Bossa Nova Brazilian Cuisine',
#  'Wokcano - Downtown LA',
#  'Carousel Restaurant',
#  "Nick & Stef's Steakhouse",
#  'Fratelli Cafe',
#  'Yardbird Southern Table & Bar',
#  'Caffe Pinguini',
#  'Chiba Restaurant',
#  'Running Goose',
#  "Barney's Beanery",
#  'Golden Road Brewing',
#  'LA Prime at The Westin Bonaventure Hotel',
#  "Cliff's Edge",
#  'Zinc Cafe Market & Bar',
#  'Mercado',
#  'Sidewalk Cafe',
#  'The Cafe',
#  'Stella Barra Hollywood',
#  'The Tasting Kitchen',
#  "Clifton's",
#  'The Serving Spoon Restaurant',
#  'Trastevere Ristorante Italiano',
#  'Mels Drive-In',
#  'Pasta Sisters',
#  "Factor's Famous Deli",
#  "Denny's",
#  'Maude',
#  'Katsuya - LA Live',
#  'Wolfgang Puck at Hotel Bel-Air',
#  'The Raymond Restaurant',
#  'Los Toros Mexican Restaurant',
#  'Gracias Madre',
#  "Morton's The Steakhouse",
#  "Lala's Argentine Grill",
#  'Pizzicotto',
#  'Il Fornaio',
#  'Palermo Ristorante Italiano',
#  'Son of a Gun',
#  'Osteria Mamma',
#  "Nick's Cafe",
#  'Noe Restaurant & Bar',
#  'Boa',
#  'El Paseo Inn',
#  'Tsujita LA Artisan Noodle',
#  'Loteria Grill',
#  'Pizzeria Il Fico',
#  'Piccolo Paradiso',
#  'The Waffle',
#  'Asanebo',
#  'Mama Restaurant Los Angeles',
#  'Brera Ristorante',
#  'Urth Caffe',
#  'Pomodoro Trattoria - Pizzeria',
#  "Jon & Vinny's",
#  'Real Food Daily - West Hollywood',
#  'Vibrato Grill Jazz...etc.',
#  'Umami Burger',
#  "Cici's Cafe",
#  'Bao Dim Sum House',
#  "Miceli's",
#  'BCD Tofu House',
#  'Firefly',
#  'Bandera',
#  'Plant Food and Wine',
#  'Granville',
#  'Sur Restaurant & Grill',
#  'Ramen Tatsunoya',
#  'Sizzler',
#  'The Butcher, The Baker, The Cappuccino Maker',
#  'The Hummus Bar & Grill',
#  'Patys Restaurant',
#  'Little Next Door',
#  'BOA Steakhouse',
#  'The Smoke House',
#  "Rao's",
#  '22nd Street Landing Seafood Grill & Bar',
#  'Figaro Bistrot',
#  'Trattoria Amici',
#  'The Royce at The Langham',
#  'Kanpai Sushi Bar and Grill',
#  'Gladstones',
#  'Au Lac Dtla',
#  'Casablanca',
#  'Versailles Cuban Restaurant',
#  'Tavern Restaurant',
#  'Guisados',
#  'Terroni',
#  "Joe's Falafel",
#  'kitchen24',
#  'Little Sister',
#  "Tony Roma's",
#  'Inn of the Seventh Ray',
#  'Terroni - LA',
#  'Pink Taco',
#  'Patina Restaurant',
#  'District',
#  'San Antonio Winery',
#  'Candle Cafe & Grill',
#  'Cantalinis Salerno Beach Restaurant',
#  'Shojin Organic and Natural',
#  'Spago Beverly Hills',
#  '10e Restaurant',
#  'Takami Sushi and Robata',
#  'NBC Seafood',
#  'Chosun Galbee Restaurant',
#  'Messhall',
#  "L'Antica Pizzeria Da Michele",
#  "Cafe 50's",
#  'Yard House',
#  'Silver Lake Ramen',
#  'Malbec Argentinean Cuisine',
#  'Chateau Marmont',
#  "Grill 'Em All Alhambra",
#  'N.10 Restaurant',
#  'Umami Burger',
#  'Public Kitchen and Bar',
#  'Orsa & Winston',
#  'Badmaash',
#  'The Whale & Ale',
#  'Las Vegas Seafood Buffet',
#  'San Pedro Brewing Company',
#  'Tender Greens',
#  'Il Cielo',
#  'Chichen Itza',
#  'The Standard Downtown Restaurant & Lounge',
#  'Don Cuco',
#  'Wolfgang Puck Bistro',
#  'Restaurant Hama',
#  'Odys and Penelope',
#  'Los Gringos Locos',
#  'Central Grille',
#  'Osawa Pasadena',
#  "Nat's Early Bite",
#  'Wood & Vine',
#  'Marino',
#  'Tortilla Republic Grill & Tequileria',
#  'West Restaurant and Lounge',
#  'Ta-eem Grill',
#  'Casa Sanchez',
#  'Bar Ama',
#  "Dinah's Family Restaurant",
#  "Hugo's",
#  "Bea Bea's",
#  "Miceli's",
#  'Traxx Restaurant and Bar',
#  'Pacific Diner',
#  'Plan Check Kitchen',
#  'La Bruschetta Ristorante',
#  "Ray's and Stark Bar",
#  'Bourbon Steak Los Angeles',
#  "Greenblatt's",
#  'The Kitchen',
#  'KazuNori',
#  'Colori Kitchen',
#  'SOL Mexican Cocina',
#  'Eat',
#  "The Original Farmer's Market",
#  'Barrique Venice',
#  "Yuca's Hut",
#  'Jacks N Joe',
#  'Amarone Kitchen & Wine',
#  'Palm Thai Restaurant',
#  'IHOP',
#  'The Dresden Room',
#  'izaka-ya by katsuya',
#  'The Golden State',
#  'Pizzana',
#  "Doomie's",
#  'Toi on Sunset',
#  'Il Capriccio on Vermont',
#  'Black Market Liquor Bar',
#  'Shin-Sen-Gumi LA',
#  "mao's kitchen",
#  'Malbec',
#  'A-Frame',
#  'Public School 213',
#  'IHOP',
#  'Katsuya Brentwood',
#  'Congregation Ale House',
#  'Hinoki & the Bird',
#  "Paco's Tacos",
#  'Smorgasburg LA',
#  'Salt Air',
#  'Panda Express',
#  "Denny's",
#  'Fabiolus Cucina',
#  'Majordomo',
#  'Square One Dining',
#  'Prosecco Trattoria',
#  'Baltaire Restaurant',
#  'Cafe Gratitude',
#  "Millie's",
#  'Rossoblu',
#  'Felix',
#  'LA Golondrina Mexican Cafe',
#  'Anantra Thai Restaurant',
#  "Morton's The Steakhouse",
#  'Versailles Restaurant',
#  'Iroha',
#  'Thai Pepper Restaurant',
#  "Mike & Anne's Restaurant",
#  'C.O.D',
#  'A Food Affair',
#  'Barrel & Ashes',
#  'La Fiesta Brava',
#  'Fred 62',
#  'Playa Provisions',
#  'Blue Palms Brewhouse',
#  'The French Crepe Co.',
#  'High Rooftop Lounge',
#  'Il Pastaio',
#  "Ruth's Chris Steak House - Woodland Hills",
#  'Norah',
#  'Shintaro',
#  'Solar de Cahuenga',
#  'Lunasia Dim Sum House',
#  'Palmeri',
#  'Pailin Thai Cuisine',
#  'Le Petit Paris',
#  'Saddle Ranch Chop House',
#  'SUGARFISH by sushi nozawa',
#  'Delphine Eatery & Bar',
#  'Backyard Bowls',
#  'TRIPLE 8 China Bar & Grill',
#  'Pa Ord Noodles',
#  'Beer Belly',
#  "Shiloh's",
#  "Lawry's Carvery",
#  'Gwen',
#  "Monty's Good Burger",
#  'Mistral',
#  'chi Spacca',
#  'Siamese Garden',
#  'Cheese cake factory',
#  'Shamshiri Grill',
#  'La Piazza the Grove',
#  'Taste on Melrose',
#  'The Huntington Rose Garden Tea Room',
#  "Paco's Tacos",
#  'Sushi Sasabune',
#  'Justice Urban Tavern',
#  'Pace',
#  "Cole's, Originators of the French Dip Sandwich",
#  'Mr',
#  "Maggiano's - Woodland Hills",
#  'Zinque',
#  'The Edison',
#  'Beverly Soon Tofu',
#  'EMC Seafood and Raw Bar',
#  'Snow White Cafe and Grill',
#  'The Fox and Hounds',
#  "Mastro's Steakhouse",
#  "Nick's on South Lake Avenue",
#  'El Cholo',
#  'Kura Revolving Sushi Bar',
#  'Las Fuentes Mexican Food',
#  'Hide Sushi',
#  'Firehouse',
#  'Open Sesame',
#  'Yxta',
#  'More Than Waffles',
#  'Dal Rae',
#  'Grub',
#  'Blue Ribbon Sushi Bar & Grill',
#  'Locanda Veneta',
#  "Pat's Restaurant",
#  'The Cheesecake Factory',
#  'CUT',
#  "Mary and Robb's Westwood Cafe",
#  'Bistro 45',
#  'Hooters',
#  "Randy's Donuts",
#  'Da Pasquale',
#  'Jar',
#  'Evo Kitchen',
#  'Sushi Enya',
#  "Slurpin' Ramen Bar",
#  'Casa Vega',
#  "Ruth's Chris Steak House",
#  'Spumante Restaurant',
#  'Basix Cafe',
#  'On Sunset @ Luxe Hotel Sunset Blvd',
#  '1810 Argentine Restaurant',
#  'Thai Patio',
#  'Coffee Company',
#  'JINYA Ramen Bar - Studio City',
#  'Settebello',
#  'The Counter',
#  "J Trani's Ristorante",
#  'Anarbagh Indian Cuisine',
#  'Pink Pepper',
#  'Pez Cantina',
#  'Novo Cafe',
#  'Granville',
#  'Follow Your Heart Market & Cafe',
#  'Night + Market',
#  'Carousel Restaurant',
#  'Mama Lu Dumpling House Mp',
#  'The Tripel',
#  "Bob's Big Boy Burbank",
#  'Buca di Beppo Italian Restaurant',
#  'Ramen Hood',
#  '800 Degrees',
#  "Nonna's Empanadas",
#  'Buffalo Wild Wings',
#  "Taylor's Steakhouse",
#  'Kali Restaurant',
#  'The Great Greek Restaurant and Taverna',
#  'Il Piccolino Trattoria',
#  'Le Petit Greek',
#  'Pump Lounge',
#  'Golden Deli Vietnamese',
#  'Hoy-Ka Thai Noodle House',
#  'M Grill',
#  "Cindy's Eagle Rock",
#  'Salsa & Beer',
#  'Lunas Restaurant',
#  'El Portal Restaurant',
#  'Chado Tea Room',
#  "Skaf's Lebanese Cuisine",
#  'Little Beast Restaurant',
#  'Cafe Beaujolais',
#  'Lum-Ka-Naad Thai Restaurant',
#  'French Market Cafe',
#  'Cafe Crepe',
#  'My Two Cents',
#  "Ruth's Chris Steak House",
#  'The Local Peasant - Sherman Oaks',
#  'Ivory on Sunset',
#  'Saladang Garden',
#  'The Village Idiot',
#  'Century Taproom',
#  'Jaipur Cuisine of India',
#  "Joe's Pizza on Hollywood",
#  'Sushi Stop',
#  'Think Cafe',
#  'Ago Restaurant',
#  'M Cafe Melrose',
#  'Blu Jam Cafe',
#  'Met Her At A Bar',
#  'La Luz del Dia',
#  'Cafe Sierra',
#  'Simpang Asia',
#  "Trader Joe's",
#  'The Waterfront Venice',
#  'WoodSpoon',
#  'The Tap Room at The Langham',
#  'Post & Beam',
#  'Loteria Grill',
#  'Cabo Wabo Cantina',
#  'Eat This Cafe',
#  'The Grill on the Alley',
#  'LA Market',
#  'The Counter Miracle Mile',
#  'Oliva Trattoria',
#  'El Pollo Loco',
#  'Jaffa',
#  'Hangar 18',
#  'Red Lobster',
#  'Yard House',
#  'Mijares Mexican Restaurant',
#  'Toca Madera',
#  'The Tower Bar',
#  'Kura Revolving Sushi Bar',
#  'Sushi Roku',
#  'Urban Plates',
#  'THEBlvd Prive',
#  "Chi Chi's Pizza",
#  'Johnny Rockets',
#  'Umami Burger',
#  'Checkers Downtown',
#  'Robata JINYA - Hollywood',
#  'Gusto',
#  'Costero California Bar + Bistro',
#  'Sushi by H',
#  'Boneyard Bistro',
#  'Road to Seoul',
#  'Panini Cafe',
#  "Gloria's Cafe",
#  "Fleming's Prime Steakhouse & Wine Bar",
#  'Carnival Restaurant',
#  'Sugarfish by Sushi Nozawa',
#  'Jane Q',
#  'Alejos Presto Trattoria Italian Restaurant',
#  "Mel's Drive-In",
#  'Drago Ristorante',
#  "Italy's Little Kitchen",
#  'Night + Market',
#  "Gus's World Famous Fried Chicken",
#  'Sidewalk Grill',
#  'Cavatina',
#  'Ostrich Farm',
#  'LACMA Cafe',
#  "Jimmy Buffett's Margaritaville",
#  'Ysabel',
#  '94th Aero Squadron Restaurant & Events',
#  "Harold and Belle's",
#  'Casa Bianca Pizza Pie',
#  'Tibet Nepal House',
#  'Blaze Pizza',
#  'Bossa Nova Brazilian Cuisine',
#  "John O' Groats",
#  "Mauro's Cafe & Ristorante",
#  'Le Pain Quotidien',
#  'Spire 73',
#  'Panini Kabob Grill - Downtown L.A.',
#  'Erewhon',
#  'Cicada Restaurant',
#  'Petty Cash Taqueria & Bar',
#  'Grand Cafe Omni Hotel',
#  'Nook Bistro',
#  'Cleo Third Street',
#  'The Six',
#  "Pie n' Burger",
#  'Shabu Shabu House Restaurant',
#  'La Boucherie',
#  'La Noche Buena Restaurant',
#  'Jitlada Restaurant',
#  'The Eveleigh',
#  'Millennium Biltmore Hotel Los Angeles',
#  'The Local Peasant',
#  'La Chapter',
#  'Native Foods',
#  'Marix Tex Mex Cafe',
#  'Leo & Lily',
#  '208 Rodeo Restaurant',
#  'Humble Bee Bakery and Cafe',
#  'Cafe Vida',
#  "It's Pho",
#  'Bonaventure Brewing Co.',
#  'Kiwami',
#  'The Edmon',
#  "Singapore's Banana Leaf",
#  "Trejo's Cantina",
#  "Joe's Cafe",
#  'Le Pain Quotidien',
#  'Cacao Mexicatessen',
#  'Darya Restaurant Santa Monica',
#  'Lunasia',
#  "Fleming's Prime Steakhouse & Wine Bar",
#  'Sweet Chick',
#  'Los Balcones del Peru',
#  'Tuning Fork',
#  'Taqueria Los Anaya',
#  'Harvest Moon Kitchen and Marketplace',
#  'Sushi Dan',
#  'E.P & L.P',
#  'JOEY Woodland Hills',
#  'The Arbour',
#  'Suehiro Cafe',
#  'Pacific Dining Car',
#  'Kabuki',
#  'Sanamluang Cafe',
#  'Hot & Juicy Crawfish',
#  'Saint Felix Hollywood',
#  'Lido Pizza',
#  'STK Steakhouse',
#  'Bollywood Cafe',
#  'Golden Dragon Restaurant',
#  'Cafe Stella',
#  'Canoe House',
#  'The Spare Room',
#  'Engine Co',
#  'Poppy & Rose',
#  'Pitfire Artisan Pizza',
#  "Benny's Tacos & Chicken Rotisserie",
#  "Lala's",
#  'Lucky Baldwins Pub',
#  'Vegas Seafood Buffet',
#  'Lemonade',
#  'The Grain Cafe',
#  'Wahlburgers',
#  'Kanpai Sushi Bar and Grill',
#  'La Cabana Restaurant',
#  'Tipsy Cow',
#  'Baramee Thai Restaurant',
#  'La Rose Cafe',
#  'El Carmen',
#  'The Exchange Restaurant',
#  "Blair's",
#  'Il Fornaio',
#  'Kino Sushi',
#  'Sushi Roku Pasadena',
#  'barbrix',
#  "Mario's Peruvian & Seafood",
#  'Homegirl Cafe',
#  'Hangari Kalguksu',
#  "Rocco's Pizza",
#  'Cho Oishi',
#  'The Cat & Fiddle Pub and Restaurant',
#  "Fisherman's Outlet Restaurant and Market",
#  'Eastside Market',
#  'The Bunker Hill Bar & Grill',
#  "Smeraldi's",
#  'The Bellwether',
#  'Ocho Mexican Grill',
#  "Tara's Himalayan Cuisine",
#  'Library Bar',
#  'The Pikey',
#  'Lemonade',
#  'Soot Bull Jeep',
#  'Sunny Spot',
#  'Delancey',
#  "Hoy's Wok Restaurant",
#  "Vito's Pizza",
#  "Maria's Italian Kitchen",
#  'Omelette & Waffle Shop',
#  'Salvatore Italian Restaurant',
#  'Vegan House in Hollywood',
#  'California Pizza Kitchen Pasadena',
#  'kitchen24',
#  'Veggie Grill',
#  'Upstairs at the Ace Hotel',
#  'Hamasaku',
#  'Skylight Gardens',
#  'La Paella',
#  'Il Fornaio Cucina Italiana - Woodland Hills',
#  "Senor G's Restaurant",
#  'Cherry Pick Cafe',
#  'Tallyrand',
#  'Far Bar',
#  'Soul Restaurant & Bar',
#  'Cooks County',
#  'Natalee Thai',
#  'Alimento',
#  'Franklin & Company Tavern',
#  'Pastina',
#  'Marouch Lebanese Restaurant',
#  'Sun Nong Dan',
#  "Morton's The Steakhouse",
#  "Tom's Watch Bar",
#  'Olio',
#  'Kagura Downtown',
#  'Wirtshaus',
#  "Smitty's Grill",
#  'Sawyer',
#  'JINYA Ramen Express',
#  'Tumanyan Khinkali Factory',
#  'Baroo',
#  'Preux & Proper',
#  'Bacari Playa del Rey',
#  'Mantee Cafe',
#  'Phoenix Inn Chinese Cuisine',
#  'E.A.K',
#  'Fundamental',
#  'Green Earth Vegan Cuisine',
#  "Sarita's Pupuseria",
#  'Blossom Restaurant',
#  'The Larchmont',
#  'Public School 818',
#  "Roscoe's House of Chicken & Waffles",
#  'Il Moro',
#  'The Roof',
#  'Cafe Los Feliz',
#  'Clementine',
#  'Fish Grill',
#  'Maximiliano',
#  'Wood Ranch BBQ & Grill',
#  "Craig's",
#  "Nick's Coffee Shop & Deli",
#  'Plancha - A Taco Joint',
#  'Sunnin Lebanese Cafe',
#  'Jones',
#  'Unity LA Restaurant',
#  'California Chicken Cafe',
#  'Goldies',
#  'Scratch Bar & Kitchen',
#  'Runway',
#  "Davenport's Restaurant",
#  "The Park's Finest",
#  'Souplantation',
#  'Birds Rotisserie Chicken Cafe and Bar',
#  'Tender Greens',
#  "Lola's Peruvian Restaurant",
#  "Dave's Hot Chicken",
#  'Stella Barra Pizzeria & Wine Bar',
#  "Uncle Bernie's Deli",
#  "Hal's Bar & Grill",
#  'Sprazzo',
#  "Pagliacci's",
#  "Govinda's Natural Food Restaurant",
#  'EnjoEat Classico',
#  'Shin Ramen',
#  'Red Herring',
#  'Momed',
#  'Fish Grill',
#  'Genghis Cohen',
#  "Father's Office",
#  'JeJe Chicken',
#  'Village Pizzeria',
#  'Oak Tree Inn',
#  'Midici The Neapolitan Pizza Company',
#  'The Ramen Joint',
#  'Honor Bar',
#  'Taste at the Palisades',
#  'Greenleaf Chopshop',
#  'Sushi Go 55',
#  'Little Damage',
#  'Sushi Zo',
#  'Cafe Verona',
#  'Borneo Kalimantan Cuisine',
#  'Red Lion Tavern',
#  'Santouka Ramen',
#  'South Beverly Grill',
#  'Horseless Carriage Restaurant',
#  'El Cochinito Restaurant',
#  "Scarantino's Italian Inn",
#  'Marmalade Cafe',
#  'NORMS Restaurant',
#  'The Counter',
#  'Nate N Als',
#  'Dirt Dog',
#  'Miro',
#  'Zankou Chicken',
#  'Claim Jumper Restaurants',
#  'Bacari GDL',
#  'Spring',
#  'Stone Brewing Tap Room - Pasadena',
#  'Country Deli and Restaurant',
#  'Panini Kabob Grill - Glendale',
#  'Wasabi',
#  '800 Degrees Pizza',
#  'Kismet',
#  'La Boheme',
#  "Nicola's Kitchen",
#  'The Bel-Air',
#  'Botanica',
#  "Pappy's Seafood",
#  "Araya's Place",
#  "Nicole's Gourmet Foods",
#  'Marugame Udon',
#  'Papilles Restaurant',
#  'South End',
#  'Panini Kabob Grill - Beverly Hills',
#  'Panzanella Ristorante',
#  'Valley Inn Restaurant and Bar',
#  'Ocean Seafood Restaurant',
#  'Sweet Butter Kitchen Cafe Market',
#  'Polo Lounge at the Beverly Hills Hotel',
#  'SUGARFISH by sushi nozawa',
#  "BJ's Restaurant & Brewhouse",
#  'Oo Kook Korean BBQ',
#  'Vespaio',
#  'Tamayo',
#  'Upstairs 2',
#  'Spring Street Smokehouse',
#  'Vincenti Ristorante',
#  "Denny's",
#  'Bar Figueroa',
#  'Le Pain Quotidien',
#  'Stoney Point Restaurant',
#  'Tel Aviv Glatt Kosher Grill',
#  'Gen Korean Bbq House',
#  'Taco Bell',
#  'Vinh Loi Tofu Vietnamese Vegan Restaurant',
#  '786 Degrees',
#  'Girasol',
#  'Osteria Venice West',
#  'Briganti',
#  'California Pizza Kitchen',
#  'Della Terra',
#  "Little Fatty's",
#  'Urban Skillet',
#  'Gingergrass',
#  'The District by Hannah An',
#  'The Fat Dog',
#  'Chipotle Mexican Grill',
#  "Here's Looking at You",
#  'Bistro De La Gare',
#  'Galanga',
#  'Subway',
#  'La Gondola',
#  'Eureka!',
#  'Divino',
#  'Orochon Ramen',
#  'The Lab Gastropub',
#  'Cafe Birdie',
#  'Plateia',
#  "Denny's",
#  'El Huarique Peruvian Cuisine',
#  'San Carlo Italian Deli',
#  'LA Casita Mexicana',
#  'Ahgassi Gopchang',
#  'Buenos Aires Grill',
#  "Robert's Russian Cuisine",
#  'Le Pain Quotidien',
#  'Four Cafe',
#  'Cascabel',
#  'Vernetti',
#  'In-N-Out Burger',
#  "Alexander's Steakhouse",
#  'Ever Bar',
#  'Sari Sari Store',
#  "Niko's Pizza",
#  'Street Churros',
#  'Katsuya',
#  'Lemonade',
#  'Bombo Foods',
#  'Sonoratown',
#  'Toscanova',
#  'City Wok',
#  "Art's Delicatessen",
#  "Salt's Cure",
#  'Cardamom Indian Cuisine',
#  "Dave & Buster's",
#  'Sushi Komasa',
#  'Mr',
#  'Samosa House',
#  "Avila's El Ranchito Mexican Restaurant",
#  'Gyu-Kaku Japanese BBQ',
#  'Max City Bbq',
#  'La Pergoletta',
#  'Monte Alban',
#  'Rodeo Mexican Grill',
#  'Metro Cafe',
#  'Panang Thai Restaurant',
#  "Charlie's Trio Cafe",
#  'Blue Dog Beer Tavern',
#  'Pizza Studio Los Angeles - USC',
#  "Jinky's Cafe",
#  'Pizza Romana',
#  'Simply Wholesome',
#  "Crazy Rock'n Sushi",
#  "Manny's Pizzeria",
#  'RH at Andaz West Hollywood Hyatt',
#  'Pecorino',
#  'Tender Greens',
#  'Bloom Cafe',
#  'Hippo',
#  'Versailles Cuban Food',
#  'Dama',
#  'Kifune Sushi Bar',
#  'Hurry Curry of Tokyo',
#  'Blue Plate Oysterette',
#  "Jameson's Irish Pub",
#  'Cafe Brasil',
#  'Arashi Sushi',
#  'Elena Greek Armenian Cuisine',
#  "Momma's Brick Oven",
#  'The Little Easy',
#  'Ekkamai Thai Restaurant',
#  'Sugarfish by Sushi Nozawa',
#  'Dreams Cafe & Bar',
#  'Nong La Cafe',
#  'Roscoes House of Chicken & Waffles',
#  'Kinnara Thai',
#  'Feast Kitchen and Grill',
#  'Whisper Restaurant & Lounge',
#  'Casita Del Campo',
#  'California Pizza Kitchen',
#  'Great Maple - Pasadena',
#  "Susan Feniger's Street",
#  'Polka',
#  'Compagnon Wine Bistro',
#  'Pink Taco',
#  "Dulan's On Crenshaw",
#  'Hollywood Thai Restaurant',
#  'Froma on Melrose',
#  'La Barca',
#  'Melrose Cafe',
#  'Han Bat Shul Lung Tang',
#  'Shu Restaurant',
#  'Arts District Brewing',
#  'Pit Fire Pizza CO',
#  'Frida Mexican Cuisine',
#  "Andre's Italian Restaurant",
#  'Brandywine',
#  'Everson Royce Bar',
#  'Gyu-Kaku Japanese BBQ',
#  'The Stocking Frame DTLA',
#  'P.F',
#  "Riordan's Tavern",
#  'Button Mash',
#  'Bar Hayama',
#  'Pf Changs',
#  'The Velvet Margarita',
#  'Las Anitas',
#  ...]

# %%
def visit_restaurant(df, want_to_go_name):
    each_name = want_to_go_name.split(".")
    
    for name in each_name:
        if name == each_name[0]:
            visit_html = df[["Restaurant Name", "Site Link"]][df["Restaurant Name"] == name]
        else:
            visit_html = visit_html.append(df[["Restaurant Name", "Site Link"]][df["Restaurant Name"] == name])
    
    return visit_html

# %% [markdown]
# ## Step 2: Ask for an input from the users

# %%
want_to_go_name = str(input("Which restaurant do you want to go?"))
visit_html = visit_restaurant(df, want_to_go_name)
# Out:
# Which restaurant do you want to go?Yamashiro Hollywood

# %%
def find_location(visit_html):
    
    location = []
    
    for link in visit_html["Site Link"]:
        html = requests.get(link)
        bsobj = soup(html.content, "lxml")
    
        for loc in bsobj.find_all("script", type = "application/ld+json"):
            if "streetAddress" in loc.string:
                find_part_html = loc.string.split("{")
                for street in find_part_html:
                    if "streetAddress" in street:
                        for value in street.split(","):
                            if "streetAddress" in value:
                                street_name = value.split(":")[1][1:][:-1] + ", "
                                   
                            if "addressLocality" in value:
                                city_name = value.split(":")[1][1:][:-1] + ", "
                                 
                            if "postalCode" in value:
                                zipcode = "CA " + value.split(":")[1][1:][:-1]
                            
        location_info = street_name + city_name + zipcode
        location.append(location_info)
    
    return location

# %%
location = find_location(visit_html)

# %%
location
# Out:
# ['1999 N Sycamore Ave, Los Angeles, CA 90068-3782']
