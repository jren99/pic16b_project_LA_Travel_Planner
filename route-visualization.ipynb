# %% [markdown]
# ### Route Visualization using Geopy, Polyline, Folium
# Using this code, we can create an interactive route visualization using Geopy, Polyline, and Folium.
#
# Originally in our project proposal we said we would use the Google Maps API, but through experimentation it proved to be difficult to work with. You can obtain an API key from Google, but a lot of features cannot be accessed unless you provide billing information to Google. If you provide billing information, there is a free version you can use, but you have a limited number of geocode requests you can make. Requests over that threshold will charge you using your billing information. That's not something that I think we want to deal with for a school project, so I tried to find some alternate methods.

# %% [markdown]
# ### Modules
# The modules we'll be using throughout the code are Pandas and Requests.
# - **Pandas**: We use Pandas to create the dataframe containing all of the addresses and their corresponding longitude and latitude coordinates. This dataframe will also be used later in selecting which specific locations we want to visualize.
# - **requests**: This module allows us to make http requests in Python. We use requests to query from OSRM and get coordinates for each of our addresses.

# %%
# main modules to use
import pandas as pd # create the locations dataframe
import requests # send http requests
# import import_ipynb
# %run webscraping_code_touristsite_all.ipynb
# %run webscraping_code_hotel_all.ipynb
# %run webscraping_code_restaurant_all.ipynb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\Anaconda3\envs\PIC16B\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     702             fpath = arg_lst[0]
# --> 703             filename = file_finder(fpath)
#     704         except IndexError:
#
# ~\Anaconda3\envs\PIC16B\lib\site-packages\IPython\utils\path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'webscraping_code_touristsite_all.ipynb.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-1-2a466190720f> in <module>
#       3 import requests # send http requests
#       4 # import import_ipynb
# ----> 5 get_ipython().run_line_magic('run', 'webscraping_code_touristsite_all.ipynb')
#       6 get_ipython().run_line_magic('run', 'webscraping_code_hotel_all.ipynb')
#       7 get_ipython().run_line_magic('run', 'webscraping_code_restaurant_all.ipynb')
#
# ~\Anaconda3\envs\PIC16B\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# <decorator-gen-53> in run(self, parameter_s, runner, file_finder)
#
# ~\Anaconda3\envs\PIC16B\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\Anaconda3\envs\PIC16B\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     712             if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     713                 warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 714             raise Exception(msg)
#     715         except TypeError:
#     716             if fpath in sys.meta_path:
#
# Exception: File `'webscraping_code_touristsite_all.ipynb.py'` not found.

# %% [markdown]
# ### Obtaining the Locations
# We create dataframes from the csv files we obtained from web scraping. They contain all of the attractions/hotels obtained from webscraping. We then take user input and create the list of attractions/hotels that they want to go to. I will add restaurants later.

# %%
# Attractions dataframe
df = pd.read_csv("2520_touristsite.csv")
df = df.drop('Unnamed: 0', 1)
df

# %%
tourist_site_names = list(df['Tourist Site Name'].unique())
tourist_site_names
# Out:
# ['The Getty Center',
#  'Griffith Observatory',
#  'Universal Studios Hollywood',
#  'Petersen Automotive Museum',
#  'The Wizarding World of Harry Potter',
#  'Battleship USS Iowa Museum',
#  'The Broad',
#  'Staples Center',
#  'Griffith Park',
#  'The Grove',
#  'La Brea Tar Pits and Museum',
#  'Walt Disney Concert Hall',
#  'Natural History Museum of Los Angeles County',
#  'Runyon Canyon Park',
#  'Venice Canals Walkway',
#  'The Nethercutt Collection',
#  'Dodger Stadium',
#  'Union Station',
#  'Hollywood Sign',
#  'Bradbury Building',
#  'Lake Hollywood Park',
#  'Universal CityWalk Hollywood',
#  'Los Angeles County Museum of Art',
#  'Madame Tussauds Hollywood',
#  'Abbot Kinney Boulevard',
#  'Angels Flight Railway',
#  'University of California, Los Angeles (UCLA)',
#  'Hollywood Forever Cemetery',
#  'Citadel Outlets',
#  'Pantages Theatre',
#  'The Hollywood Museum',
#  'OUE Skyspace LA',
#  'Los Angeles Central Library',
#  'Olvera Street',
#  'Pierce Brothers Westwood Village Memorial Park',
#  'Dolby Theatre',
#  'The Greek Theatre',
#  'City Hall',
#  'Echo Park',
#  'Urban Light',
#  'Little Tokyo',
#  'Skirball Cultural Center',
#  'Hollywood Bowl Museum',
#  'Autry Museum of the American West',
#  'San Antonio Winery',
#  'Korean Bell of Friendship',
#  'Cathedral of Our Lady of the Angels',
#  'Topanga State Park',
#  'Diorama-museum of Bhagavad-gita',
#  'Holocaust Museum LA',
#  'Venice Beach',
#  'Hollywood Walk of Fame',
#  'Will Rogers State Historic Park',
#  'Venice Skatepark',
#  'Sunset Boulevard',
#  'Stahl House',
#  'Los Angeles Zoo & Botanical Gardens',
#  'Hollywood Hills',
#  'Hollyhock House',
#  'El Pueblo de Los Angeles',
#  'University of Southern California',
#  'Museum of Illusions',
#  'The Japanese Garden',
#  'Museum of Tolerance',
#  'Annenberg Space for Photography',
#  'Studio Tour',
#  'Hollywood Farmers Market',
#  'Mission San Fernando',
#  'Melrose Avenue',
#  'Japanese American National Museum',
#  'Bronson Caves',
#  'Eames House',
#  'Hollywood Bowl Overlook',
#  'Forest Lawn Memorial Park - Hollywood Hills',
#  'Museum of Selfies',
#  'Candy Cane Lane',
#  'L.A',
#  'GRAMMY Museum',
#  'Hollywood Boulevard',
#  'Angeles Crest Highway',
#  'Jurassic Park The Ride',
#  'Koreatown',
#  'Metro Rail',
#  'Venice Beach Boardwalk',
#  'Exposition Park',
#  'Microsoft Theater',
#  'Flight Path Learning Center & Museum',
#  'Watts Towers',
#  'Chinatown',
#  'Hollywood',
#  'Revenge of the Mummy - The Ride',
#  'Hollywood Bowl',
#  'Travel Town',
#  'Orpheum Theater',
#  'Lost Spirits Distillery',
#  'Ahmanson Theatre',
#  'Beverly Center',
#  'Avila Adobe',
#  'Transformers: The Ride - 3D',
#  'Flower Market',
#  'Lake Balboa Park',
#  'Marciano Art Foundation',
#  'Samuel Oschin Air & Space Center',
#  'Hollywood Wax Museum',
#  'Museum of Death',
#  'Harry Potter and the Forbidden Journey',
#  'Wiltern Theatre',
#  'Los Angeles Convention Center',
#  'LA Fashion District',
#  'The Museum of Contemporary Art',
#  'Westfield Topanga',
#  "Ripley's Believe It or Not!",
#  'Mosaic Tile House',
#  'Playa Del Rey Beach',
#  'Temescal Gateway Park',
#  'Grand Park',
#  'Art District',
#  'Capitol Records Building',
#  'Los Angeles Memorial Coliseum',
#  'Mrs',
#  'Heritage Square Museum',
#  'Hollywood Reservoir',
#  'California African American Museum',
#  'Park La Brea',
#  'Dorothy Chandler Pavilion',
#  'Cabrillo Marine Aquarium',
#  'Wells Fargo Museum',
#  'Point Fermin Park',
#  'Hammer Museum',
#  'Dockweiler State Beach',
#  'Los Feliz',
#  'Banc of California Stadium',
#  'Will Rogers State Beach',
#  'Lake Shrine Temple and Retreat',
#  'The Santee Alley',
#  'Angelino Heights Historic Area',
#  'FIDM Museum and Galleries',
#  'Point Fermin Lighthouse',
#  'The Walking Dead Attraction',
#  'Cabrillo Beach',
#  'Bob Baker Marionette Theater',
#  'Hauser & Wirth',
#  'Downtown Historic District',
#  'Guinness World Records Museum',
#  'Wildlife Learning Center',
#  'S.S',
#  'Kenneth Hahn State Recreation Area',
#  'Geffen Playhouse',
#  'Los Angeles Police Museum',
#  'Melrose Place',
#  'Larchmont Village',
#  'Metrolink',
#  'Loyola Marymount University',
#  'La Plaza de Cultura Y Artes',
#  'Pershing Square',
#  'Greenbar Distillery',
#  'El Rey Theater',
#  'Ford Theatres',
#  'Despicable Me Minion Mayhem',
#  'Sunken City',
#  'Los Angeles Maritime Museum',
#  'The Simpsons Ride',
#  'Mildred Mathias Botanical Gardens',
#  'Valley Relics Museum',
#  "Macy's Plaza",
#  'Barnsdall Art Park',
#  'MacArthur Park',
#  'Marvin Braude Bike Trail',
#  'Venice Pier',
#  'Hollywood and Vine',
#  'Hollyridge Trail',
#  'Old Plaza Firehouse',
#  'Our Lady Queen of Angels',
#  'San Gabriel Mountains',
#  'Wisdome LA',
#  'Chinese American Museum',
#  'Lovell Health House',
#  'LAX Theme Building',
#  'Hollywood Murals-You Are the Star',
#  'Fowler Museum',
#  'Neutra VDL House',
#  'Old Plaza',
#  'Cupcake Theater',
#  'Flutter Experience',
#  'Los Angeles National Cemetery',
#  'Elysian Park',
#  'California Plaza',
#  'Silverlake Flea',
#  'Velveteria - The Museum of Velvet Paintings',
#  "Ports O' Call Village",
#  'Super Silly Fun Land',
#  'Paul Smith Los Angeles',
#  'the Row DTLA',
#  'Wat Thai of Los Angeles',
#  'Fonda theatre',
#  'Los Angeles Fire Department Museum',
#  'Bullocks Wilshire Building',
#  'Hollywood United Methodist Church',
#  'King Kong 360 3-D',
#  'Thien Hau Temple',
#  'The Music Center',
#  'Civic Center',
#  'Pico House',
#  'Los Angeles California Temple',
#  'IPIC Westwood',
#  'Lummis Home (El Alisal)',
#  'Discovery Cube Los Angeles',
#  'Flight of the Hippogriff',
#  'UCLA Athletics Hall of Fame',
#  'Museum of Broken Relationships',
#  'Valley Performing Arts Center',
#  'Museum of Neon Art (MONA)',
#  'The Chandelier Tree',
#  'Largo at the Coronet',
#  'The Banning Museum',
#  'Hillside Memorial Park',
#  'Westside Pavilion Shopping Center',
#  'Old Plaza Church',
#  'Hollywood & La Brea Gateway (The Four Ladies of Hollywood Gazebo)',
#  'Sherman Oaks Galleria',
#  'St',
#  'Los Angeles Duty Free (DFS)',
#  'Eagle Rock',
#  'US Bank Tower',
#  'Fort McArthur Military Museum',
#  'Vincent Thomas Bridge',
#  'Royal Palms State Beach',
#  'Franklin D',
#  'Monastery of the Angels',
#  'The Teragram Ballroom',
#  'Aratani Theatre',
#  'Thai Town',
#  'Italian American Museum of Los Angeles',
#  'Music Box Steps',
#  'Bunker Hill Steps',
#  'Fast and Furious - Supercharged',
#  'Simon Wiesenthal Center',
#  'Universal Plaza',
#  'Highland Park Brewery',
#  'Los Angeles Theatre',
#  'The Novo',
#  'Hollywood Christmas Parade',
#  'Universal City Overlook',
#  'The Hollywood Experience',
#  "Zimmer Children's Museum",
#  'Los Angeles Live Steamers',
#  'Million Dollar Theater',
#  'Vista Hermosa Natural Park',
#  'Hollywood Heritage Museum',
#  'La Brea Avenue',
#  'Pan Pacific Park Recreation Center',
#  'Chiat-Day Building',
#  'Beyond The Streets',
#  "Macy's 4th of July Fireworks",
#  'Holmby Park',
#  'The Regent Theater',
#  'NoHo Arts District',
#  'Sepulveda House',
#  'Rustic Canyon Park',
#  'Vista Theater',
#  'The Great Wall of Los Angeles',
#  'I Like Scary Movies Experience',
#  'Mercadito',
#  'LA Waterfront',
#  'Fine Arts Building',
#  'Upper Las Virgenes Canyon Open Space Preserve',
#  'White Point',
#  'Grand Hope Park',
#  'Nike Missile Control Site',
#  'Ken Malloy Regional Park',
#  'Drum Barracks Civil War Museum',
#  'Holyland Exhibition',
#  'Los Angeles Convention & Visitors Bureau',
#  'Los Angeles River',
#  'Sherman Oaks Antique Mall',
#  'Biscailuz Building',
#  'MAK Center for Art and Architecture -- Schindler House',
#  "Bloomingdale's",
#  'Hansen Dam Aquatic Center',
#  'Odyssey Theatre',
#  'Ernest E Debs Regional Park',
#  'The Late Late Show with Craig Ferguson',
#  'Hancock Park',
#  'Trail Canyon Falls Trail',
#  'Rancho La Brea',
#  'Terminal Island Japanese Memorial',
#  'MacLeod Ale Brewing House',
#  'Clutter’s Park',
#  'Museum of Social Justice',
#  'United Artists Theatre',
#  'Warner Grand Theatre',
#  'Leimert Park Village',
#  'Southwest Museum',
#  'Boney Island',
#  'Westridge-Canyonback Wilderness Park',
#  'Oviatt Building',
#  'Otis College of Art and Design Gallery',
#  'Ascot Hills Park',
#  'Touch of Venice mural',
#  'Los Angeles State Historic Park',
#  'Pauley Pavillion',
#  'Jackie Robinson Stadium',
#  'Nordstrom',
#  'Bank of America Building',
#  'Doheny Mansion and Chester Place',
#  'Psychiatry: An Industry of Death',
#  'Artspace Warehouse',
#  'Los Angeles Terminal Annex Post Office',
#  'Historic Theater District',
#  'US Open of Surfing',
#  'Coca-Cola Building',
#  'Galpin Auto Sports',
#  'Occidental College',
#  'Museum of Failure',
#  'Hayworth Theatre',
#  'Golden Dragon Parade',
#  'Koreatown Plaza',
#  'Metropolitan Pit Stop',
#  'Dunbar Hotel',
#  'Astronomers Monument',
#  "Farmer John's Murals at the Clougherty Packing Company",
#  'Placita de Dolores',
#  'Ballona Wetlands',
#  "Walt Disney's Carolwood Barn",
#  'Museum of Dream Space',
#  'Shrek 4-D',
#  'Crossroads of the World',
#  'The Port of Los Angeles',
#  'A+D Architecture and Design Museum',
#  'CBS Studio Center',
#  "Skipper's 22nd Street Landing",
#  'James Irvine Garden',
#  'West Los Angeles Buddhist Temple',
#  'Palace Theater',
#  'Department of Water and Power Building',
#  'Frogtown Brewery',
#  'First National Bank of Hollywood',
#  'Blessed Sacrament Catholic Church',
#  "Los Angeles Children's Museum",
#  'Stoney Point Park',
#  'San Vicente Boulevard',
#  'African American Firefighter Museum',
#  'San Fernando Mission Cemetery',
#  'World of Fruit',
#  'Little Ethiopia',
#  'East West Players',
#  'Fiesta Broadway',
#  '777 Tower',
#  'Abbot Kinney Sunday Bazaar',
#  'Belasco Theater',
#  'Westfield Fashion Square',
#  'Felipe de Neve',
#  'Globe Theatre',
#  'Old Bank District',
#  'USS Pampanito',
#  'Wilshire Boulevard Temple',
#  'Wilmington Waterfront Park',
#  "Charlie Turner's Trail",
#  'Nonaka-Hill Gallery',
#  'America Tropical Interpretive Center',
#  'Fisher Museum of Art',
#  'Mariachi Plaza',
#  'The Ebell of Los Angeles',
#  'Koyasan Buddhist Temple',
#  'Ennis House',
#  'Equestrian statue of Antonio Aguilar',
#  'UCLA Meteorite Gallery',
#  'Venice art walls',
#  'Go For Broke NEC',
#  'La Plaza United Methodist Church',
#  'Mural on the side of Venice Suites',
#  'Grier Musser Museum',
#  'Sacred Fools Theater Company',
#  'Higashi Honganji Buddhist Temple',
#  'Los Angeles River Bike Path',
#  'El Grito (the cry)',
#  'Indian Alley',
#  'Iguana Vintage Clothing',
#  'Omar ibn Al-Khattab Mosque',
#  'Los Angeles Wholesale Produce Market',
#  'Spring Street Federal Courthouse',
#  'Serenity Park Parrot Sanctuary',
#  'Real Fitness',
#  'Muller House Museum',
#  'Fahey Klein Gallery',
#  'Venice Kinesis',
#  'Los Angeles Mall',
#  'Los Encinos State Historic Park',
#  'Olvera street Cross',
#  'Pacific Opera Project',
#  "Zombie Joe's Underground Theatre",
#  'Rebel Without a Cause Monument',
#  'Ensemble Studio Theatre',
#  'Santa Ynez Canyon Park',
#  'Palace Theatre',
#  'American Film Institute',
#  'Morning Shot mural',
#  'Olde Good Things',
#  'Palisades Park and Recreation Center',
#  'Indie Brewing Company',
#  'City Hall Park',
#  'Radiant Space',
#  'Bootleg Theater',
#  '849 Building',
#  'Central Garden',
#  'The Unicorn Experience',
#  'Lincoln Park',
#  'ARCO Plaza',
#  'Cirque Du Soleil Volta',
#  'Marilyn: The Exhibit',
#  'Verdugo Hills of Peace Pioneer Cemetery',
#  'Forest Lawn Museum of Mexican and American History',
#  'Brentwood Farmers Market',
#  'Sullivan Canyon',
#  'Theatre West',
#  'Venice Beach mural',
#  'Declaration Sculpture',
#  'Doheny Memorial Library',
#  'Mount Sinai Memorial Park',
#  'Mulholland Memorial Fountain',
#  'Luminaries of Pantheism Mural',
#  'Parker Center',
#  'Hoose Library of Philosophy',
#  'Angelus Temple',
#  'United Club Lounge',
#  'Independent Shakespeare Co.',
#  'The Oakridge Estate',
#  'MorYork Gallery',
#  'Statue of King Carlos III',
#  'First African Methodist Episcopal Church',
#  'Earvin "Magic" Johnson Statue',
#  'The Bates Motel By Vincent Lamouroux',
#  'Royce Hall',
#  'Outpost Estates',
#  'Inglewood Park Cemetery',
#  'Fishing Industry Memorial',
#  'Micheleronta Stairs',
#  'Italian American Museum Of Los Angeles',
#  'First Presbyterian Church of Hollywood',
#  'The Latino Museum of History, Art and Culture',
#  'The World Stage',
#  'Cheviot Hills Recreation Center',
#  'Light My Fire',
#  'Atwater Village Theater',
#  'Ballona Freshwater Marsh',
#  'Molecule Man Sculpture',
#  'California Dreaming Mural',
#  'The Promenade At Howard Hughes Center',
#  'Powell Library',
#  'Immanuel Presbyterian Church',
#  'Solar System Lawn Model',
#  'Beautycon LA',
#  'Santa Ynez Falls Trail',
#  'Waterfront Red Car Line',
#  'Shrine Auditorium and Expo Hall',
#  'The Pupper Club',
#  'Ulysses Sculpture',
#  'Primavera Sculpture',
#  'Institute of Contemporary Art',
#  'G2 Gallery',
#  'The Hollywood Sculpture Garden',
#  'Ernie Wolfe Gallery',
#  'Seventh Street Marketplace',
#  'The Blessing of the Animals',
#  'Lowes State Theatre',
#  'United University Church',
#  'Guaranty Building',
#  'South Robertson Boulevard',
#  'Los Angeles Ballet',
#  'Velaslavasay Panorama',
#  'Father Serra Park',
#  'Tristan Eaton Mural',
#  'Rogue Machine Theatre',
#  'Studio City Golf and Tennis',
#  'Eglise San Sebastian',
#  'South Bay Bicycle Trail',
#  'Sister Cities Monument',
#  'Triforium Sculpture',
#  'Brady Bunch House',
#  'Laurel Canyon News',
#  'Nakatomi Tower',
#  'Uptown Rocker Sculpture',
#  'Museum of African American Art',
#  'Linnie Cana Park',
#  'Ace Gallery',
#  'The Fountain Theatre',
#  'Pierce Brothers Valhalla Pierce Brothers Valhalla Memorial Park',
#  'North Weddington Recreation',
#  'Butterfly garden',
#  'The Hudson Theater Mainstage',
#  'BHStar-Be A Hollywood Star',
#  'Vietnam Recognition Marker',
#  'Paul Hastings Tower',
#  'RedCat',
#  'Bolton Hall Museum',
#  'Lafayette Park',
#  'Victor Clothing',
#  'Verdugo Peak',
#  'Jill and Frank Fertitta Hall',
#  'Universal City Studios',
#  'California Aqueduct Bikeway',
#  'Little Fish Theatre',
#  'Statue of Fra Junipero Serra',
#  'LA96C',
#  'Westchester Parkway Bike Loop',
#  'Taschen Gallery',
#  'Plaza de la Raza Cultural Center',
#  'Andres Pico Adobe',
#  'Los Angeles Theatre Center',
#  'Continental Building',
#  '"So far so good" mural',
#  'Wiretap Brewing',
#  'Kingdom Day Parade',
#  'Twentieth Church of Christ',
#  'Blacker House',
#  'Stocker Corridor Trail',
#  "Old Trapper's Lodge",
#  'Herald Examiner Building',
#  'Public Art "You Are Not Forgotten"',
#  'First Congregational Church of Los Angeles',
#  'The Annunciation',
#  'Pellissier building',
#  'Rhodes Jewish Museum',
#  'Hollywoodland Antiques & Fine Time Pieces',
#  'The Globe Theatre',
#  'Audubon Center at Debs Park',
#  'Pierce College',
#  'Merced Theatre',
#  'Ukrainian Culture Center',
#  'McDonalds Swim Stadium',
#  'Masonic Hall',
#  "Brandelli's Brig mural",
#  'Marabella Vineyard Company',
#  'Impro Theatre',
#  "Freak's Antiques",
#  'Porter Valley Winery',
#  '"Walk a Mile in My Shoes" Civil Rights Memorial',
#  'Richard Alatorre Park',
#  'Aon Center',
#  'Milk and Honey Contemporary Art in California',
#  '444 Flower Building',
#  'Corita Art Center',
#  'First Baptist Church of Hollywood',
#  'The Main Museum',
#  'Zen Center of Los Angeles',
#  'Westchester Recreation Center',
#  'CSUN Orange Grove and Pond',
#  '24th Street Theatre',
#  'Nick Metropolis',
#  'Silly Swirly Fun Ride',
#  'University of Southern California, Hertha and Walter Klinger Gallery',
#  'Tower Theatre',
#  'KP Projects',
#  'Brunswig Building',
#  'Cactus Gallery',
#  'Rex Dinosaur',
#  'West Angeles Church of God in Christ',
#  'Leo S Bing Theater',
#  'MonteVerde Trails Ranch',
#  'African American Cultural Center',
#  'Highland Camrose park',
#  'San Pedro Theatre Club',
#  'Lankershim Art Gallery',
#  'Hurricane Hollywood',
#  'Ahavat Torah Synagogue',
#  'PlaylandRus',
#  'Canoga-Owensmouth Historical Museum',
#  'Rugrats Mural',
#  'Makeshift Museum',
#  'Los Angeles Contemporary Exhibitions',
#  'Harris & Ruble Building',
#  'Studio for Southern California History',
#  'Apex Fine Art',
#  'The Little Theater',
#  'Abbot Kinney Memorial Branch Library',
#  'Simpson Jones Building',
#  'Hellman/Quon Building',
#  'Crown City Theater',
#  'Sunset and Moonset Radial Lines',
#  'Turner building',
#  'The Coast Playhouse',
#  'Hollywood Cherokee Building',
#  'Alabama Antiques',
#  'Chioschi per mangiare di vari etnie',
#  'The Porters of Hellsgate',
#  'World Pa Kua Martial Arts and Health',
#  'East Meets West Antiques',
#  'We Love LA Tour',
#  'Golden Ticket LA',
#  'Bikes And Hikes LA',
#  'La La Tours',
#  'Aloha Brothers Surf Lessons',
#  'LA Platinum Tour And Transportation',
#  'Your L.A',
#  'Hollywood Hikes',
#  'LA Fly Rides',
#  'Kapowui Surf Lessons',
#  'A Day in LA Tours',
#  'Freedom Tours & Charters - LA Tours',
#  'MidWilShuttle',
#  'Architecture Tours L.A.',
#  'Sandra & Dennis - Deine deutschen Reiseleiter in Los Angeles',
#  'Six Taste',
#  'Tourific Escapes',
#  'Virtual Room Los Angeles',
#  'Another Side Of Los Angeles Tours',
#  "Scot Nery's Boobietrap",
#  'LA Insider Tours',
#  'Handlebar Bike Tours',
#  'Bike Tours Hollywood',
#  'Elite Helicopter Tours',
#  'Guideline Tours',
#  'i Ride Like a Star',
#  'ExperienceFirst',
#  'Melting Pot Food Tours',
#  'Hollywood Classic Tours',
#  'LA Hood LIfe Tours',
#  'Secret Food Tours Los Angeles',
#  '60out Escape Rooms - West Los Angeles',
#  'Learn To Surf LA',
#  'Legends Of Hollywood Tours',
#  'Fun Surf LA',
#  'LA Walking Tours',
#  'Los Angeles Urban Adventures',
#  'Fantastic Race',
#  'The Real Los Angeles Tours',
#  'Amoeba Music',
#  'Sidewalk Food Tours of Los Angeles',
#  'Hollywood City Tours',
#  'The Basement A Live Escape Room Experience',
#  'Self Realization Fellowship Lake Shrine Temple',
#  'Ultimate Hollywood Tours',
#  'Hollywood LA Tours',
#  'Dearly Departed Tours',
#  'California Science Center',
#  'Avital Food Tours',
#  'Red Line Tours',
#  'Sunset Ranch Hollywood',
#  '360 LA Tours',
#  'iFLY Hollywood',
#  'El Capitan Theatre',
#  'The Last Bookstore',
#  'Museum Hack LA',
#  'Open Bus Tours',
#  'The Magic Castle',
#  'American Riviera Private Tours',
#  'LB Limousine',
#  'PanIQ Room Hollywood',
#  'Best Coast Tours',
#  'Guitar Center',
#  'ArcLight Cinemas',
#  'Access Hollywood Tours',
#  'The Original Farmers Market',
#  'Paramount Pictures Studio Tour',
#  'Classic Experiences',
#  'MagIQ Room',
#  'All Star Showbiz Tours',
#  'Magic and Wine Tasting with David Minkin',
#  'The Big Red Bus Company',
#  'LA Beer Hop',
#  'LayoverStop Tours',
#  'Los Angeles Philharmonic',
#  'Elite Adventure Tours',
#  'Los Angeles Off Road',
#  'Felix In Hollywood Tour Company',
#  'Golden Wave Surf School',
#  'U Ride',
#  'Westfield Century City',
#  'BonBon Safety - Outdoor Gun Shooting Tour in Los Angeles',
#  'Califun',
#  'Classic Hollywood Tours',
#  'The Escape Revolution',
#  'UNIQ Yacht Charters',
#  'Grand Central Market',
#  'TMZ Celebrity Tour',
#  'Tours By Locals',
#  'Entasis Architectural Day Tours',
#  '60Out Escape Rooms - S Figueroa',
#  'LA City Tours',
#  'Los Angeles Club Crawl - LA Epic Club Crawls',
#  "Clifton's Living History Tour",
#  'Crown Limousine',
#  'Sunny Day Scoot',
#  'LA Cycle Tours',
#  'Pacific Blue Air',
#  'LifeRush Adventures',
#  'GS Transportation Los Angeles',
#  'Beverly Hills Tours',
#  'TCL Chinese Theatres',
#  'Coast To Costa',
#  'Hollywood & Highland',
#  'Los Angeles Supercar Tour by Exotics Racing',
#  'La La Land',
#  'Guia Turismo Los Angeles',
#  'The Los Angeles Experience',
#  'Go Ride Shuttle Service',
#  'Tzedek America',
#  'Two Bit Circus',
#  'Group 3 Aviation',
#  'Angel City Brewery',
#  'Zippy Shuttle',
#  'Starline Tours',
#  'Los Angeles Conservancy Walking Tours',
#  'Proper Sightseeing',
#  'Ride Free Motorcycle Tours and Rentals',
#  'Mojo Maps Expedition Co.',
#  'Synaptic Cycles Bicycle Rentals',
#  'Wheel Fun Rentals Echo Park',
#  'LA Art Tours',
#  'Comtecierge',
#  'Star Track Tours',
#  'Quest Room',
#  'The Groundlings Theatre',
#  'Hollywood Club Crawl',
#  'The Virus Escape Room presented by Get the F Out',
#  'Go Legendary Los Angeles',
#  'Mickey’s Space Ship Shuttle',
#  'Albertson Wedding Chapel',
#  'Oldies Tours',
#  'Stash House',
#  'TNT Tours & Limo Services',
#  'Big Bus Tours Los Angeles',
#  'Hard Rock Cafe',
#  'Hollywood Tourz',
#  'Hollywood Tours.LA',
#  'Frolic Room',
#  'Luxe Vegan Food Tours',
#  'Eat Sleep Surf',
#  'The Los Angeles Gun Club',
#  'Temple Surf',
#  'The Theatre at Ace Hotel',
#  'UCLA Store',
#  'CharlieTheTraveler',
#  'Los Angeles Opera',
#  'Britney Spears The Zone Experience',
#  'Empire Vacations Day Tours',
#  'Escape Room LA',
#  'Muscle Beach Venice',
#  'No Vacancy',
#  'Movie Star Home Tours',
#  'Ride! Venice',
#  'CBS Television City',
#  'los angeles and beverly hills tours',
#  'Venice Street Art Tours',
#  "Mondrian's Skybar",
#  'Desuar Spa',
#  'Cool LA Tours',
#  'The Baked Potato',
#  'SoCal Brew Bus',
#  'FIGat7th',
#  'Old Hollywood Walking Tour',
#  'LAdventure Tour',
#  'WaterWorld',
#  'LA Stories',
#  'Architect Escape Rooms',
#  'Dreamscape',
#  'Escape Hotel Hollywood',
#  'CoPilot Rides',
#  'Prime Time Hollywood Tours',
#  "Good Times at Davey Wayne's",
#  'Olympic Spa',
#  'Hollywood Bus Tours',
#  'Upright Citizens Brigade Theatre LA',
#  'Wine and Dine Walking Tours',
#  'American Girl Place Los Angeles',
#  'HIHO Tours',
#  'Logiquit',
#  'Vip Mustang Tours',
#  'Los Angeles Horseback Riding',
#  'Maze Rooms',
#  'The Improv',
#  '60out Escape Rooms Melrose',
#  'Scoot A City',
#  'Hatch Escapes',
#  'Melrose Trading Post',
#  'Lucky Strike Live Hollywood',
#  'Escape the Room LA',
#  'Lite Flight Helicopters',
#  "Dave & Buster's - Arcade",
#  'Tiki Ti',
#  'Be Relax',
#  'Suv2Lax',
#  'Funko Hollywood',
#  'Riz Limo',
#  'City Wander Walks LA',
#  'The Federal',
#  'Los Angeles Bikers',
#  'Signature Hollywood Tours',
#  'Crumbs & Whiskers',
#  'Preferred Sightseeing',
#  'RapidShuttle',
#  'Fantastic Race Worldwide',
#  'Los Angeles USA Tours',
#  'Jetboy Helicopters - Day Tours',
#  'LA Experience Tours',
#  'Mark Taper Forum',
#  'Escapedom',
#  'Black Rabbit Rose',
#  'Lansky Transportation',
#  'GreenLuxTours',
#  'Seven Bar Lounge',
#  'The Rooftop at The Standard Downtown LA',
#  'Fugetsu-Do',
#  'Liza Shtromberg Jewelry',
#  'Taste of Korea Los Angeles Food Tours',
#  'Escape Room Games',
#  'Windsports Hang Gliding',
#  'Canyon Country Store',
#  'Highland Park Bowl',
#  'Tesloop',
#  'Venice Bike Tours',
#  'Free Tours by Foot Los Angeles',
#  'Craft Contemporary',
#  'High Rooftop Lounge',
#  'Prime Time Hollywod Tours',
#  "Moe's Tavern",
#  'Virtual Reality Games',
#  "Boardner's",
#  'WeekendsFrom',
#  'Cinemark Playa Vista and XD',
#  'Eaglerider Motorcycle Rentals',
#  'Dr',
#  'Soap Plant/La Luz de Jesus',
#  'Universal Studio Store',
#  'Brouwerij West',
#  'Santa Barbara & Solvang Tours - Saloon Car Tourist',
#  'Peace Awareness Labyrinth and Gardens',
#  'Hollywood Star City Tours',
#  'Official Walking Tours',
#  'Pan Am Experience',
#  'Studio City Farmers Market',
#  'VIP Hollywood Tours',
#  'Egyptian Theatre',
#  'Hollyweird Ghost Tours',
#  'LA Hemp Tours',
#  'Small World Books',
#  'Rotor F/X',
#  '60out Escape Rooms - N Western',
#  'Amazing Escape Room',
#  'Boomtown Brewery',
#  'The NoMad Hotel',
#  'Formosa Cafe',
#  'Nation Tours',
#  'CheapShuttle Express',
#  "Dylan's Candy Bar",
#  'Spaahbulous & More',
#  'Rage Ground',
#  'Bristol Farms',
#  'SouthCal Surf Lessons',
#  'The Class Limo',
#  'Southwest Adventures Day Tours',
#  'Los Angeles Ghost Tours',
#  'The Quest Factory Escape Rooms',
#  'AMC Theater',
#  'LAX FlyAway',
#  "Nic's Martini Lounge",
#  'Eightytwo',
#  'Esotouric Bus Adventures',
#  'The Dog Cafe',
#  "Universal's Animal Actors",
#  'Beverly Hot Springs Spa',
#  'Izakaya & BAR Fu-ga',
#  'Offbeat Los Angeles',
#  'Hollywood Palladium',
#  'Lalaland Tours-Charters-Events',
#  'Hollywoodland Tours',
#  'LA Hollywood Tours',
#  'LA Waterfront Cruises',
#  'Regal Cinema',
#  'LA Active Adventure Tours',
#  'Cinespia Cemetery Screenings',
#  'Sam First',
#  'Rooftop Cinema Club',
#  'Art Muse Los Angeles - Tours',
#  'The Laboratory Escape Room',
#  'Bike Rentals LA',
#  'Unplug Meditation',
#  'Evil Genius Escape Rooms',
#  'Ole Henriksen Face/Body',
#  'The Magic Show at The Roosevelt',
#  'TravelDrivers',
#  'Elephant Tour',
#  'Angeles National Golf Club',
#  'Sweet! Hollywood',
#  'Build Your Tours',
#  '7 Grand',
#  'Whimsic Alley',
#  'The Classic Neon Cruise',
#  'New Beverly Cinema',
#  'Charming Travel Destinations',
#  'Hollywood Stars Tours',
#  'Tour of the Los Angeles - Tours',
#  'Leelavadee Thai Wellness Center',
#  'Skeletons in the Closet',
#  'Resident',
#  'Mushroom Rally',
#  'UCB Theater Sunset',
#  'Spirit Cruises',
#  'The Riviera Country Club',
#  'Escape Chronicles',
#  'Black Tie Car Service',
#  'The Room: Live Escape Room LA',
#  'Wasteland',
#  'LA River Kayak Safari',
#  'Adventure LA',
#  'ClubhopLA',
#  'Blue Whale',
#  'VIP Tours',
#  'Sherman Oaks Castle Park',
#  'BEACH NOW',
#  'Virtual Reality Arcade Hollywood',
#  'The Mayan Theatre',
#  'Venice Segway Rental',
#  'ParkPlace Cali Tours',
#  'Catalina Bar and Grill',
#  'Arka Designs Fine Jewelry',
#  'Los Virtuality - Virtual Reality Gaming Center',
#  'Broadway Walking Tour Los Angeles',
#  'Akbar',
#  'Hike the Hollywood Sign',
#  'Go Los Angeles',
#  'Piano Bar',
#  'Take My Mother Please Tours',
#  'The Hidden Passage Live Escape Room Games',
#  'City Sightseeing Los Angeles',
#  'The Los Angeles Hiking Company',
#  'Bike Curious Rentals',
#  'Standard Downtown',
#  'Adam Tourguide',
#  'Graff Tours',
#  'Club Hop L.A',
#  'Star City Tours - Private Tours',
#  'MB2 Raceway Sylmar',
#  'Sky Bar',
#  'A la Carte Tours',
#  'Dresden Room',
#  'Hollywood Sightseeing Tours',
#  'Special Effects Show',
#  'Zen Zone',
#  'LetterPress Chocolate',
#  'Los Angeles Conservancy',
#  'The Mint',
#  'Great Expectations Travels - Day Tours',
#  'Hollywood Sightseeing LA',
#  'Los Angeles Club Crawl',
#  'Moore N Moore',
#  'Ranger Ted',
#  'ComedySportz Los Angeles',
#  'QUEST ROOM',
#  'Sky Zone Trampoline Park',
#  'Universal Cinema',
#  "Let's Make A Deal",
#  'Club Nokia',
#  'StreetVelo Tours',
#  'Los Angeles Boulders',
#  'Friendly Local Guides',
#  'Horror Escapes LA',
#  'Golden Gopher',
#  'Regency Village Theatre',
#  'Los Angeles Helicopter Tours',
#  "Casey's Irish Pub",
#  'LA Day Tour',
#  'Titanic Boutique',
#  'Arclight Cinema',
#  'Plan Check',
#  'Kitson',
#  'Kwik-E-Mart',
#  'Power House',
#  '60out Escape Rooms Koreatown',
#  'Back In Time Escape Rooms',
#  'Bar Marmont',
#  'Bar Covell',
#  'Nature Spa',
#  'Los Angeles Times Headquarters',
#  'Winnetka Bowl',
#  'Boulevard3',
#  'Century Day & Night Spa',
#  'Laurel Cannyon',
#  'IMAX VR',
#  'Los Angeles Country Club',
#  'Cinco',
#  'EagleRider Rentals and Tours',
#  'Level Up Hollywood Hip-Hop Tours',
#  'Enchanted Escape Room',
#  "Collector's Paradise",
#  'Dublins Irish Whisky Pub',
#  'Duff Brewery Beer Garden',
#  'Out & About Tours',
#  "Molly Malone's",
#  'Same Day Marriage',
#  'My Valley Pass',
#  'Birds and Bees',
#  'Late Late Show with James Corden',
#  'Pour Vous',
#  'Cozymeal',
#  'Ye Rustic Inn',
#  'Good Luck Bar',
#  'Bigfoot Lodge East',
#  'LA AX',
#  'Nomoon Travel',
#  ...]

# %%
want_to_go_name = str(input("Which tourist sites do you want to go? (*please input the names of the tourist sites separated by a period)"))
# Out:
# Which tourist sites do you want to go? (*please input the names of the tourist sites separated by a period)Stahl House.Museum of Illusions

# %%
import import_ipynb
from ipynb.fs.full.webscraping_code_touristsite_all import visit_html, find_location
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-126-69474dd3f683> in <module>
#       1 import import_ipynb
# ----> 2 from ipynb.fs.full.webscraping_code_touristsite_all.ipynb import visit_html, find_location
#
# ModuleNotFoundError: No module named 'ipynb.fs.full.webscraping_code_touristsite_all.ipynb'; 'ipynb.fs.full.webscraping_code_touristsite_all' is not a package

# %%
visit_html = visit_tourist(df, want_to_go_name)

# %%
# list of attractions
locations = find_location(visit_html)
locations
# Out:
# ['1635 Woods Dr, Los Angeles, CA 90069-1633"',
#  '6751 Hollywood Blvd, Los Angeles, CA 90028-4623"']

# %%
# Hotels dataframe
hotels = pd.read_csv("450_hotel.csv")
hotels = hotels.drop('Unnamed: 0', 1)
hotels
# Out:
#      Rank                            Hotel Name              Rate  \
# 0       1                       Hollywood Hotel    4 of 5 bubbles
# 1       2     Hilton Los Angeles/Universal City    4 of 5 bubbles
# 2       3                           Hotel Erwin  4.5 of 5 bubbles
# 3       4                        Hotel Figueroa  4.5 of 5 bubbles
# 4       5                 Loews Hollywood Hotel  4.5 of 5 bubbles
# ..    ...                                   ...               ...
# 445   208                         One Ten Motel  3.5 of 5 bubbles
# 446   216                       Casa Luan Motel  4.5 of 5 bubbles
# 447   223  Howard Johnson Plaza Wilshire Royale    4 of 5 bubbles
# 448   224               Travelodge Hotel At LAX    5 of 5 bubbles
# 449   234         Best Western Premier NoHo Inn    3 of 5 bubbles
#
#                                              Site Link
# 0    https://www.tripadvisor.com//Hotel_Review-g326...
# 1    https://www.tripadvisor.com//Hotel_Review-g326...
# 2    https://www.tripadvisor.com//Hotel_Review-g326...
# 3    https://www.tripadvisor.com//Hotel_Review-g326...
# 4    https://www.tripadvisor.com//Hotel_Review-g326...
# ..                                                 ...
# 445  https://www.tripadvisor.com//Hotel_Review-g326...
# 446  https://www.tripadvisor.com//Hotel_Review-g326...
# 447  https://www.tripadvisor.com//Hotel_Review-g326...
# 448  https://www.tripadvisor.com//Hotel_Review-g326...
# 449  https://www.tripadvisor.com//Hotel_Review-g326...
#
# [450 rows x 4 columns]

# %%
hotel_want_to_go_name = str(input("Which hotel do you want to live?"))
hotel_visit_html = visit_hotel(hotels, hotel_want_to_go_name)
# Out:
# Which hotel do you want to live?Loews Hollywood Hotel

# %%
# list of hotels
hotel_location = find_location(hotel_visit_html)
hotel_location
# Out:
# ['1755 North Highland Avenue, Los Angeles, CA 90028-4403',
#  '1755 North Highland Avenue, Los Angeles, CA 90028-4403']

# %% [markdown]
# ### Geocoding
# Another module we will be using is **Geopy**, which is a Python client for geocoding. What is geocoding?
#
# **Geocoding** is the process of taking some text-based description of a location (usually the address) and transforming it into coordinates, using the longitude/latitude pair. We will use geocoding to transform the addresses of our hotel/attraction locations (obtained from webscraping) into longitude/latitude coordinates (as far as I know, TripAdvisor doesn't provide coordinates).
#
# From the Geopy module, we will use **Nominatim**, which is a geocoder for **OpenStreetMap (OSM)** data. OSM is a map of the world that is open data, licensed under the Open Database License. As such, we will credit OSM at the end of the notebook. You can check out OSM here:
#
# https://www.openstreetmap.org/

# %%
from geopy.geocoders import Nominatim # Geopy is a Python client for geocoding. We use the Nominatim geocoder for OpenStreetMap (OSM) data.

# %% [markdown]
# We create a sample locations dataframe using Nominatim geocoding. First, we clean up the list of addresses using the location_cleaner method. This ensures that we will be able to geocode all of the addresses (since OSM sometimes has trouble recognizing addresses that have extra details).
#
# Then, we create the attractions dataframe and hotels dataframe by adding their address and longitude/latitude coordinates.

# %%
# import re

# %%
# Cleans the addresses by removing the code at the end and then removing the last word of the address with each iteration of
# the loop. OSM sometimes has trouble recognizing addresses that have extra details in the middle of their addresses. 
def location_cleaner(locations):
    locations_copy = []
    for location in locations:
        location = location.rsplit(' ', 1)[0]
        words = location.split()
        location_length = len(words)
        for i in range(location_length, 0, -1):
            if geolocator.geocode(location) != None:
                locations_copy.append(location)
                break
            location = location.rsplit(' ', 1)[0]
    return locations_copy

# %%
geolocator = Nominatim(user_agent = "pic16b")

# %%
df = pd.DataFrame(columns = ["Address", "Longitude", "Latitude"]) # creating the Pandas dataframe

locations = location_cleaner(locations)
for location in locations:
    loc = geolocator.geocode(location) # geocoding the location
    df.loc[len(df.index)] = [loc, loc.longitude, loc.latitude] # adding the location, longitude, and latitude to the dataframe
    
df
# Out:
#                                              Address   Longitude   Latitude
# 0  (Case Study House No. 22, 1635, Woods Drive, H... -118.370138  34.100400
# 1  (6751, Hollywood Boulevard, Whitley Heights Hi... -118.337259  34.101472

# %% [markdown]
# We can see that we have obtained the longitude and latitude for each address and we have successfully added the data to a Pandas dataframe. A quick Google search tells us that our coordinates are pretty accurate, up to about 3 decimal places.

# %%
# may or may not need a dataframe depending on if we allow a user to stay at multiple hotels
hotel = pd.DataFrame(columns = ["Address", "Longitude", "Latitude"]) # creating the Pandas dataframe

hotel_locations = location_cleaner(hotel_location)
print(hotel_locations)
for location in hotel_locations:
    loc = geolocator.geocode(location) # geocoding the location
    location_dict = {"Address" : loc, "Longitude": loc.longitude, "Latitude" : loc.latitude}
    hotel = hotel.append(location_dict, ignore_index = True) # adding the location, longitude, and latitude to the dataframe
    
hotel
# Out:
# ['1755 North Highland Avenue, Los Angeles, CA', '1755 North Highland Avenue, Los Angeles, CA']
#                                              Address   Longitude   Latitude
# 0  (1755, North Highland Avenue, Hollywood, Los A... -118.338602  34.102842
# 1  (1755, North Highland Avenue, Hollywood, Los A... -118.338602  34.102842

# %%
hotel = hotel.drop_duplicates(subset = ["Longitude", "Latitude"])
hotel
# Out:
#                                              Address   Longitude   Latitude
# 0  (1755, North Highland Avenue, Hollywood, Los A... -118.338602  34.102842

# %%
hotel.iloc[0]["Address"]
# Out:
# Location(1755, North Highland Avenue, Hollywood, Los Angeles, California, 90028, United States, (34.10284167850925, -118.3386019049562, 0.0))

# %% [markdown]
# ### Creating the Route Visualization
# Now that we have our addresses and coordinates within a Pandas dataframe, we can begin to construct the route visualization. For this section, I mainly referenced this article: https://www.thinkdatascience.com/post/2020-03-03-osrm/osrm/
#
# In the article, Mr. Yan makes use of **Open Source Routing Machine (OSRM)**, which is a C++ routing engine for the shortest paths in road networks. Essentially, you use the requests module to perform an http request, obtaining route data for the routes between your specified locations. You can learn more about OSRM and how to construct requests here: http://project-osrm.org/docs/v5.7.0/api/?language=Python#general-options
#
# For the route visualization, we also import the **Folium** and **Polyline** modules.
# - **Folium**: The folium module takes location and route data and plots it on an interactive map.
# - **Polyline**: The polyline module is the Python implementation of Google's Encoded Polyline Algorithm Format, which allows you to store a series of coordinates as an encoded string. You can read about it here: https://developers.google.com/maps/documentation/utilities/polylinealgorithm

# %%
import folium # visualizes data on map; wondering if I can replace this with plotly express
import polyline # Python implementation of Google’s Encoded Polyline Algorithm Format

# %% [markdown]
# Let's attempt to get the route between the Griffith Observatory and Universal Studios Hollywood. We specify our request url to be the default OSRM url, followed by the mode of transportation (car) and the coordinates for our locations. The first pair of coordinates corresponds to the Griffith Observatory, and the second pair corresponds to Universal Studios Hollywood.

# %%
# The following code will be based on the code in the above article. I don't fully understand what it's doing yet, but I'm 
# hoping to get some more practice with it so I can understand it better.

# url = "http://router.project-osrm.org/route/v1/car/-118.475712,34.076951;-118.300293,34.118219;-118.361879,34.138321" # we specify the long/lat coordinates of our starting point and our ending point, as well as mode of transportation; hopefully we can add more waypoints and get the route between multiple locations
# r = requests.get(url) # getting the request
# res = r.json()
# res

# %% [markdown]
# We have successfully run the request! From the above results, we get what seems to be some interesting data but also a lot of gibberish. I believe those are the routes and locations that are encoded using Google's Polyline Algorithm. Now, let's attempt to break down the more interesting parts of the data (bear with me, this is new to me as well):
# - **Waypoints**: A waypoint is an intermediate point or place on a route. In our case, we get a list of all the locations we travel to in our route. For this example, we only have two locations, our starting point and ending point, so only two locations show up in the waypoints list. This leads me to believe that it is highly possible to construct a route between multiple sightseeing locations and a hotel location, which is one of the goals of our project.
# - **Routes**: The routes list contains the routes used to travel between the different locations. In our example, we only have two locations, our starting point and ending point, so there is only one route. I believe that if we add more locations, we will get more routes.
#     - **Geometry**: This encoding gives us the line representing the route.
#     - **Distance**: The distance specified per entry in the routes list gives the distance in meters that the route covers.
#     - **Duration**: The duration specified per entry in the routes list gives the duration of the trip in seconds.

# %%
# We use the polyline module to decode the encoding into coordinates. Not entirely sure what all of the coordinates mean but 
# I'm guessing they represent locations of different streets when you're changing streets? I don't really know; this requires
# further investigation.

# polyline.decode('yj~nEh|brUzG~AeAhH~IwBjL}Tx_@eXag@wIkDoGpFyHzkBo{Ahk@yT{@iGmTyhAuwD{iGu_AcjBy@whHacAJU}kBkd@a@aT_kBqZyI{Xf`@{\\hJlGdJZ|VnG_L|MkAqW}AeGyOz\\iJ`Y{^jZlHpSjkBbNXSxgBc_@~s@cz@rWshAfgAsVj{@qNpQcC}D')

# %% [markdown]
# ### Creating the Travel Plan
# From our attractions dataframe we can create a sample travel plan for the user. This will be a random itinerary for the user depending on how long they plan to travel. We will determine how many attractions they need to visit per day in order to visit all of the places they want. We will also create separate visualizations for each of the days. Each route will start at the user's hotel and end at the final location (which is randomly determined - I might have to experiment to see if I can generate the shortest route **per day**, though I feel this might be a lot of extra work to complete).

# %%
# user input
travel_length = input("How many days will your travel be? ")
coordinates, addresses = locations_per_day(df, travel_length)
coordinates
# Out:
# How many days will your travel be? 1
# [[(-118.3372585, 34.1014721), (-118.37013841063524, 34.1004003)]]

# %%
addresses
# Out:
# [[Location(6751, Hollywood Boulevard, Whitley Heights Historic District, Hollywood, Los Angeles, California, 90028, United States, (34.1014721, -118.3372585, 0.0)),
#   Location(Case Study House No. 22, 1635, Woods Drive, Hollywood Hills West, Los Angeles, California, 90069, United States, (34.1004003, -118.37013841063524, 0.0))]]

# %%
import random

# %%
# Determines the number of attractions that the user must visit per day and randomly chooses attractions for each day.
def locations_per_day(df, travel_length):
    travel_length = int(travel_length)
    loc_per_day = []
    number_of_locs = df.shape[0]
    while travel_length != 0:
        loc_per_day.append(number_of_locs // travel_length)
        number_of_locs -= (number_of_locs // travel_length)
        travel_length -= 1
    random.shuffle(loc_per_day) # obtain a random ordering of locations per day
    
    coordinates = [0] * len(loc_per_day)
    used_coordinates = []
    addresses = [0] * len(loc_per_day)
    
    # creates nested lists of tuples within a list that indicate the coordinates of the places you visit per day
    for i in range(len(coordinates)):
        coordinates[i] = []
        addresses[i] = []
        for j in range(0, loc_per_day[i]):
            row = df.sample()
            long_lat = (row.iloc[0]["Longitude"], row.iloc[0]["Latitude"])
            while long_lat in used_coordinates:
                row = df.sample()
                long_lat = (row.iloc[0]["Longitude"], row.iloc[0]["Latitude"])
            coordinates[i].append(long_lat)
            used_coordinates.append(long_lat)
            addresses[i].append(row.iloc[0]["Address"])
            
    
    return (coordinates, addresses)

# %% [markdown]
# #### Old get_route Function
# Obsolete, do not run!

# %%
# Putting what we did before into a function. We get the route between the two locations provided we have the coordinates
# for the locations. Ideally, I will get the coordinates from the Pandas dataframe, though I'm still figuring that out.
def get_route_old(lon_0, lat_0, lon_1, lat_1, lon_2, lat_2):
    
    loc = "{},{};{},{};{},{}".format(lon_0, lat_0, lon_1, lat_1, lon_2, lat_2)
    url = "http://router.project-osrm.org/route/v1/car/"
    r = requests.get(url + loc) # same thing as what we did before, getting the request
    print(r.status_code)
    if r.status_code!= 200: # I don't know what this means
        return {}
  
    res = r.json()   
    routes = polyline.decode(res['routes'][0]['geometry']) # the geometry specifies the polyline encoding; I'm also guessing that if we have more routes we would do this for each of the routes, with the index changing for each route
    start_point = [res['waypoints'][0]['location'][1], res['waypoints'][0]['location'][0]] # 0th waypoint corresponds to the starting location
    end_point = [res['waypoints'][1]['location'][1], res['waypoints'][1]['location'][0]] # 1st waypoint corresponds to the ending location
    distance = res['routes'][0]['distance']
    
    out = {'route':routes,
           'start_point':start_point,
           'end_point':end_point,
           'distance':distance
          } # returning a dictionary with the routes, starting point, ending point, and distance

    return out

# %% [markdown]
# #### New get_route Function
# This function generates a route for each day (nested list of coordinates). The route begins at the hotel, passes through several tourist site waypoints, and ends at the final tourist site. The user can specify what mode of transportation they want to use.

# %%
def get_route(coordinates, hotel, transportation):
    loc = str(hotel.iloc[0]["Longitude"]) + "," + str(hotel.iloc[0]["Latitude"]) + ";"
    for i in range(len(coordinates)):
        if i == len(coordinates) - 1:
            loc += str(coordinates[i][0]) + "," + str(coordinates[i][1])
        else:
            loc += str(coordinates[i][0]) + "," + str(coordinates[i][1]) + ";"
    # loc += str(hotel.iloc[0]["Longitude"]) + "," + str(hotel.iloc[0]["Latitude"]) # unaable to perform round trip
    url = "https://routing.openstreetmap.de/routed-" + transportation + "/route/v1/driving/"
    r = requests.get(url + loc + "?steps=true") # same thing as what we did before, getting the request
    if r.status_code!= 200:
        print("Failed")
        return {}
  
    res = r.json()   
    routes = polyline.decode(res['routes'][0]['geometry']) # the geometry specifies the polyline encoding
    start_point = [res['waypoints'][0]['location'][1], res['waypoints'][0]['location'][0]] # 0th waypoint corresponds to the starting location
    end_point = [res['waypoints'][len(res['waypoints']) - 1]['location'][1], res['waypoints'][len(res['waypoints']) - 1]['location'][0]] # len - 1 waypoint corresponds to the ending location
    waypoints = []
    for i in range(1, len(res['waypoints']) - 1):
        waypoints.append((res['waypoints'][i]['location'][1], res['waypoints'][i]['location'][0]))
    distance = res['routes'][0]['distance']
    duration = res['routes'][0]['duration']

    out = {'route':routes,
           'start_point':start_point,
           'waypoints': waypoints,
           'end_point':end_point,
           'distance':distance,
           'duration':duration
          } # returning a dictionary with the routes, starting point, ending point, and distance

    return out

# %%
transportation = str(input("What mode of transportation would you like to use? Specify car, bike, or foot. "))
# Out:
# What mode of transportation would you like to use? Specify car, bike, or foot. car

# %%
# obtain the list of routes for the entire travel
route_list = []
for i in range(len(coordinates)):
    test_route = get_route(coordinates[i], hotel, transportation)
    route_list.append(test_route)
route_list
# Out:
# [{'route': [(34.10284, -118.33873),
#    (34.10155, -118.33872),
#    (34.10155, -118.33726),
#    (34.10156, -118.33701),
#    (34.10054, -118.33699),
#    (34.10054, -118.33871),
#    (34.09798, -118.33868),
#    (34.09808, -118.36044),
#    (34.09797, -118.36672),
#    (34.0996, -118.36712),
#    (34.10001, -118.36702),
#    (34.09996, -118.36768),
#    (34.10057, -118.36749),
#    (34.10059, -118.36837),
#    (34.10095, -118.36817),
#    (34.10105, -118.36828),
#    (34.10105, -118.36898),
#    (34.10078, -118.36912),
#    (34.09988, -118.36829),
#    (34.09958, -118.3683),
#    (34.09997, -118.36935),
#    (34.09989, -118.36979),
#    (34.1, -118.37013)],
#   'start_point': [34.102842, -118.338725],
#   'waypoints': [(34.101554, -118.33726)],
#   'end_point': [34.099999, -118.370134],
#   'distance': 4409.3,
#   'duration': 504.9}]

# %%
for route_leg in route_list[0]["route"]:
    print(route_leg)
# Out:
# (34.10284, -118.33873)
# (34.10155, -118.33872)
# (34.10155, -118.33726)
# (34.10156, -118.33701)
# (34.10054, -118.33699)
# (34.10054, -118.33871)
# (34.09798, -118.33868)
# (34.09808, -118.36044)
# (34.09797, -118.36672)
# (34.0996, -118.36712)
# (34.10001, -118.36702)
# (34.09996, -118.36768)
# (34.10057, -118.36749)
# (34.10059, -118.36837)
# (34.10095, -118.36817)
# (34.10105, -118.36828)
# (34.10105, -118.36898)
# (34.10078, -118.36912)
# (34.09988, -118.36829)
# (34.09958, -118.3683)
# (34.09997, -118.36935)
# (34.09989, -118.36979)
# (34.1, -118.37013)

# %%
# list of colors for plotting different routes
list_colors = [
    "red",
    "orange",
    "yellow",
    "green",
    "blue",
    "purple"
]

# %% [markdown]
# ### Creating the Maps
# We plot an individual route and specify the route color (this is mostly to differentiate the routes). We use a green play icon to indicate the starting point, a red stop icon to indicate the ending point, and a blue icon to indicate waypoints.

# %%
# Using folium to draw the route on an interactive map. Since none of us are really familiar with folium, it would be worth
# seeing if we can accomplish the same results but using plotly express instead.
def get_map(route, route_color, addresses):
    
    m = folium.Map(location=[(route['start_point'][0] + route['end_point'][0])/2, 
                             (route['start_point'][1] + route['end_point'][1])/2], 
                   zoom_start=15, tooltip = "Hover")

    folium.PolyLine(
        route['route'],
        weight=8,
        color=route_color,
        opacity=0.6
    ).add_to(m)

    folium.Marker(
        location=route['start_point'],
        icon=folium.Icon(icon='play', color='green'),
        popup = hotel.iloc[0]["Address"]
    ).add_to(m)

    folium.Marker(
        location=route['end_point'],
        icon=folium.Icon(icon='stop', color='red'),
        popup = addresses[len(addresses) - 1]
    ).add_to(m)
    
    for i in range(len(route['waypoints'])):
        folium.Marker(
            location=route['waypoints'][i],
            icon=folium.Icon(icon='circle', color='blue'),
            popup = addresses[i]
        ).add_to(m)

    return m

# %%
# Getting the map for our test route
maps = []
for i in range(len(route_list)):
    maps.append(get_map(route_list[i], list_colors[i], addresses[i]))

# %%
for i in range(0, len(maps)):
    print("Day {}".format(i + 1))
    print("The trveling distance is {} m".format(route_list[i]["distance"]))
    print("The traveling duration is {} min".format(route_list[i]["duration"] / 60))
    display(maps[i])
# Out:
# Day 1
# The trveling distance is 4409.3 m
# The traveling duration is 8.415 min
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_549d444ce6cf422cb1920ff4c7d3b1af%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_549d444ce6cf422cb1920ff4c7d3b1af%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_549d444ce6cf422cb1920ff4c7d3b1af%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_549d444ce6cf422cb1920ff4c7d3b1af%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B34.1014205%2C%20-118.3544295%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# This code was made possible by OSM (© OpenStreetMap contributors).
#
# Copyright info for OSM: https://www.openstreetmap.org/copyright

# %% [markdown]
# **Note**: This code is not completely up-to-date with the route-visualization code in the Flask webapp. This code provides most of the framework; however, the code in the webapp has been adjusted to fix the issue of entering a number of days greater than the number of tourist attractions.
